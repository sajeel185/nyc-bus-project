# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from scipy import stats
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn import ensemble
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
import datetime
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import f_classif
import geopy.distance
from sklearn.pipeline import Pipeline
from datetime import timedelta

# %%
df = pd.read_csv('nyc bus data.csv')
df = df.drop_duplicates()
# = df.dropna()
df.head()
# Out:
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (14,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   RecordedAtTime  DirectionRef PublishedLineName                 OriginName  \
# 0  6/1/2017 0:03             0                B8                 4 AV/95 ST
# 1  6/1/2017 0:03             1               S61  ST GEORGE FERRY/S61 & S91
# 2  6/1/2017 0:03             0              Bx10     E 206 ST/BAINBRIDGE AV
# 3  6/1/2017 0:03             0                Q5           TEARDROP/LAYOVER
# 4  6/1/2017 0:03             1               Bx1      RIVERDALE AV/W 231 ST
#
#    OriginLat  OriginLong                  DestinationName  DestinationLat  \
# 0  40.616104  -74.031143          BROWNSVILLE ROCKAWAY AV       40.656048
# 1  40.643169  -74.073494                S I MALL YUKON AV       40.575935
# 2  40.875008  -73.880142                 RIVERDALE 263 ST       40.912376
# 3  40.701748  -73.802399    ROSEDALE LIRR STA via MERRICK       40.666012
# 4  40.881187  -73.909340  MOTT HAVEN 136 ST via CONCOURSE       40.809654
#
#    DestinationLong VehicleRef  VehicleLocation.Latitude  \
# 0       -73.907379   NYCT_430                 40.635170
# 1       -74.167686  NYCT_8263                 40.590802
# 2       -73.902534  NYCT_4223                 40.886010
# 3       -73.735939  NYCT_8422                 40.668002
# 4       -73.928360  NYCT_4710                 40.868134
#
#    VehicleLocation.Longitude            NextStopPointName  \
# 0                 -73.960803            FOSTER AV/E 18 ST
# 1                 -74.158340      MERRYMOUNT ST/TRAVIS AV
# 2                 -73.912647  HENRY HUDSON PKY E/W 235 ST
# 3                 -73.729348     HOOK CREEK BL/SUNRISE HY
# 4                 -73.893032     GRAND CONCOURSE/E 196 ST
#
#   ArrivalProximityText DistanceFromStop ExpectedArrivalTime  \
# 0          approaching               76       6/1/2017 0:03
# 1          approaching               62       6/1/2017 0:03
# 2              at stop                5       6/1/2017 0:03
# 3        < 1 stop away              267       6/1/2017 0:04
# 4              at stop               11       6/1/2017 0:03
#
#   ScheduledArrivalTime Unnamed: 17
# 0             24:06:14         NaN
# 1             23:58:02         NaN
# 2             24:00:53         NaN
# 3             24:03:00         NaN
# 4             23:59:38         NaN

# %%
df.shape
# Out:
# (1048575, 18)

# %%
#checking for column types and missing data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 18 columns):
# RecordedAtTime               1048575 non-null object
# DirectionRef                 1048575 non-null int64
# PublishedLineName            1048575 non-null object
# OriginName                   1040112 non-null object
# OriginLat                    1040112 non-null float64
# OriginLong                   1040112 non-null float64
# DestinationName              1048575 non-null object
# DestinationLat               1047329 non-null float64
# DestinationLong              1047329 non-null float64
# VehicleRef                   1048575 non-null object
# VehicleLocation.Latitude     1048575 non-null float64
# VehicleLocation.Longitude    1048575 non-null float64
# NextStopPointName            1047439 non-null object
# ArrivalProximityText         1047439 non-null object
# DistanceFromStop             1047439 non-null object
# ExpectedArrivalTime          931342 non-null object
# ScheduledArrivalTime         1022903 non-null object
# Unnamed: 17                  59 non-null object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 152.0+ MB

# %% [markdown]
# The data had several columns with missing data.  As can be seen in the next cell, I used the ffill() method to fill in the missing data.

# %%
#filling in missing data 
df['OriginName'].ffill(axis=0, inplace=True)
df['OriginLat'].ffill(axis=0, inplace=True)
df['OriginLong'].ffill(axis=0, inplace=True)
df['DestinationLat'].ffill(axis=0, inplace=True)
df['DestinationLong'].ffill(axis=0, inplace=True)
df['DistanceFromStop'].ffill(axis=0, inplace=True)
df['ArrivalProximityText'].ffill(axis=0, inplace=True)
df['NextStopPointName'].ffill(axis=0, inplace=True)
df['ExpectedArrivalTime'].ffill(axis=0, inplace=True)
df['ScheduledArrivalTime'].ffill(axis=0, inplace=True)

# %%
#examining "ExpectedArrivalTime" column
df['ExpectedArrivalTime'].head()
# Out:
# 0    6/1/2017 0:03
# 1    6/1/2017 0:03
# 2    6/1/2017 0:03
# 3    6/1/2017 0:04
# 4    6/1/2017 0:03
# Name: ExpectedArrivalTime, dtype: object

# %%
#examining "ScheduledArrivalTime" column
df['ScheduledArrivalTime'].head()
# Out:
# 0    24:06:14
# 1    23:58:02
# 2    24:00:53
# 3    24:03:00
# 4    23:59:38
# Name: ScheduledArrivalTime, dtype: object

# %% [markdown]
# The "ExpectedArrivalTime" and "ScheduledArrivalTime" columns both need to be cleaned and formatted into proper datetime columns.  The "ScheduledArrivalTime" column is missing the date, and its midnight hour needs to be properly formatted to "00".
#
# I used the split() method to split the date and time portions of the "ExpectedArrivalTime", and save the date into a new column called "expected_date".
#
# I then applied a lambda function to "ScheduledArrivalTime" and used the replace() method to correct the midnight hour from "24" to "00".
#
# I will then join "expected_date" with "ScheduledArrivalTime" to create a proper datetime column.  Please see below

# %%
#splitting 'ExpectedArrivalTime' column
expected_split = df['ExpectedArrivalTime'].str.split(expand=True)
print(expected_split.head())
# Out:
#           0     1
# 0  6/1/2017  0:03
# 1  6/1/2017  0:03
# 2  6/1/2017  0:03
# 3  6/1/2017  0:04
# 4  6/1/2017  0:03

# %%
#creating new feature; the 'expected_date' column
df['expected_date'] = expected_split[0]

# %%
#formatting the 'ScheduledArrivalTime'
df['ScheduledArrivalTime'] = df['ScheduledArrivalTime'].apply(lambda x: x[0:2].replace('24', '00')) + df['ScheduledArrivalTime'].apply(lambda x: x[2:])

# %%
#examining the 'ScheduledArrivalTime' column
df['ScheduledArrivalTime'].head()
# Out:
# 0    00:06:14
# 1    23:58:02
# 2    00:00:53
# 3    00:03:00
# 4    23:59:38
# Name: ScheduledArrivalTime, dtype: object

# %%
#creating new feature'Scheduled_datetime' column
df['Scheduled_datetime'] = df['expected_date'] + ' ' + df['ScheduledArrivalTime']

# %%
#examining 'Scheduled_datetime' column
df['Scheduled_datetime'].head()
# Out:
# 0    6/1/2017 00:06:14
# 1    6/1/2017 23:58:02
# 2    6/1/2017 00:00:53
# 3    6/1/2017 00:03:00
# 4    6/1/2017 23:59:38
# Name: Scheduled_datetime, dtype: object

# %%
#converting 'Scheduled_datetime' to datetime object
df['Scheduled_datetime'] = pd.to_datetime(df['Scheduled_datetime'], errors='coerce')

# %%
#converting 'Expected_arrival' column to datetime object
df['Expected_datetime'] = pd.to_datetime(df['ExpectedArrivalTime'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1048575 entries, 0 to 1048574
# Data columns (total 21 columns):
# RecordedAtTime               1048575 non-null object
# DirectionRef                 1048575 non-null int64
# PublishedLineName            1048575 non-null object
# OriginName                   1048575 non-null object
# OriginLat                    1048575 non-null float64
# OriginLong                   1048575 non-null float64
# DestinationName              1048575 non-null object
# DestinationLat               1048575 non-null float64
# DestinationLong              1048575 non-null float64
# VehicleRef                   1048575 non-null object
# VehicleLocation.Latitude     1048575 non-null float64
# VehicleLocation.Longitude    1048575 non-null float64
# NextStopPointName            1048575 non-null object
# ArrivalProximityText         1048575 non-null object
# DistanceFromStop             1048575 non-null object
# ExpectedArrivalTime          1048575 non-null object
# ScheduledArrivalTime         1048575 non-null object
# Unnamed: 17                  59 non-null object
# expected_date                1048575 non-null object
# Scheduled_datetime           1041552 non-null datetime64[ns]
# Expected_datetime            1048507 non-null datetime64[ns]
# dtypes: datetime64[ns](2), float64(6), int64(1), object(12)
# memory usage: 176.0+ MB

# %%
#filling in missing data
df['Scheduled_datetime'].ffill(axis=0, inplace=True)
df['Expected_datetime'].ffill(axis=0, inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 1048516

# %% [markdown]
# The above null values are in the "Unnamed" column, which I will drop later

# %% [markdown]
# In the "Scheduled_datetime" column the actual date near the midnight hour should one day before the date listed.  I will apply a lambda function to subtract one day from the date in the datetime for all observations where the value equals '23'.  Please see below.

# %%
#fixing the date value, by subtracting one day, for those datetime entries where the hour is near midnight.
df['Scheduled_datetime'] = df['Scheduled_datetime'].apply(lambda x: x - timedelta(days=1) if str(x)[11:13] == '23' else x)

# %%
#create new feature to record the difference between each bus's scheduled arrival time and expected arrival time.
df['delay'] = df['Expected_datetime'] - df['Scheduled_datetime']

# %%
df.head()
# Out:
#   RecordedAtTime  DirectionRef PublishedLineName                 OriginName  \
# 0  6/1/2017 0:03             0                B8                 4 AV/95 ST
# 1  6/1/2017 0:03             1               S61  ST GEORGE FERRY/S61 & S91
# 2  6/1/2017 0:03             0              Bx10     E 206 ST/BAINBRIDGE AV
# 3  6/1/2017 0:03             0                Q5           TEARDROP/LAYOVER
# 4  6/1/2017 0:03             1               Bx1      RIVERDALE AV/W 231 ST
#
#    OriginLat  OriginLong                  DestinationName  DestinationLat  \
# 0  40.616104  -74.031143          BROWNSVILLE ROCKAWAY AV       40.656048
# 1  40.643169  -74.073494                S I MALL YUKON AV       40.575935
# 2  40.875008  -73.880142                 RIVERDALE 263 ST       40.912376
# 3  40.701748  -73.802399    ROSEDALE LIRR STA via MERRICK       40.666012
# 4  40.881187  -73.909340  MOTT HAVEN 136 ST via CONCOURSE       40.809654
#
#    DestinationLong VehicleRef        ...                   NextStopPointName  \
# 0       -73.907379   NYCT_430        ...                   FOSTER AV/E 18 ST
# 1       -74.167686  NYCT_8263        ...             MERRYMOUNT ST/TRAVIS AV
# 2       -73.902534  NYCT_4223        ...         HENRY HUDSON PKY E/W 235 ST
# 3       -73.735939  NYCT_8422        ...            HOOK CREEK BL/SUNRISE HY
# 4       -73.928360  NYCT_4710        ...            GRAND CONCOURSE/E 196 ST
#
#    ArrivalProximityText DistanceFromStop ExpectedArrivalTime  \
# 0           approaching               76       6/1/2017 0:03
# 1           approaching               62       6/1/2017 0:03
# 2               at stop                5       6/1/2017 0:03
# 3         < 1 stop away              267       6/1/2017 0:04
# 4               at stop               11       6/1/2017 0:03
#
#   ScheduledArrivalTime Unnamed: 17 expected_date  Scheduled_datetime  \
# 0             00:06:14         NaN      6/1/2017 2017-06-01 00:06:14
# 1             23:58:02         NaN      6/1/2017 2017-05-31 23:58:02
# 2             00:00:53         NaN      6/1/2017 2017-06-01 00:00:53
# 3             00:03:00         NaN      6/1/2017 2017-06-01 00:03:00
# 4             23:59:38         NaN      6/1/2017 2017-05-31 23:59:38
#
#     Expected_datetime             delay
# 0 2017-06-01 00:03:00 -1 days +23:56:46
# 1 2017-06-01 00:03:00          00:04:58
# 2 2017-06-01 00:03:00          00:02:07
# 3 2017-06-01 00:04:00          00:01:00
# 4 2017-06-01 00:03:00          00:03:22
#
# [5 rows x 22 columns]

# %%
#creating new feature called 'Scheduled_HourOfDay', to reflect relationship of the time of day and whether or not a bus is on time.
#Certain bus routes may be effected by non controllable conditions such as traffic, which is more of a factor during rush hour
#and accounting for the hour of day may help the model capture that relationship. 
df['Scheduled_HourOfDay'] = df['Scheduled_datetime'].dt.hour

# %%
#creating a new feature "delay_second" to equate 'delay' column in seconds
df['delay_second'] = df['delay'].dt.seconds

# %%
#creating new feature 'delay_minute' to convert the delay_second to minutes
df['delay_minute'] = df['delay_second'] / 60

# %%
df.delay.value_counts().head(10)
# Out:
# 00:01:00             21215
# 00:00:00             20973
# 00:02:00             19748
# -1 days +23:59:00    18994
# 00:03:00             17457
# 00:04:00             15582
# -1 days +23:58:00    14392
# 00:05:00             13712
# 00:06:00             12310
# 00:07:00             10952
# Name: delay, dtype: int64

# %% [markdown]
# The "delay" feature in the dataset has some values that are negative in days.  To explore this further, I am going to extract the days from the "delay" column to get more insight into the data.

# %%
#creating new feature delay_days by extracting the day value from 'delay' column.  
df['delay_days'] = df['delay'].dt.days

# %%
df.head(10)
# Out:
#   RecordedAtTime  DirectionRef PublishedLineName  \
# 0  6/1/2017 0:03             0                B8
# 1  6/1/2017 0:03             1               S61
# 2  6/1/2017 0:03             0              Bx10
# 3  6/1/2017 0:03             0                Q5
# 4  6/1/2017 0:03             1               Bx1
# 5  6/1/2017 0:03             0                M1
# 6  6/1/2017 0:03             0               B31
# 7  6/1/2017 0:03             0               B83
# 8  6/1/2017 0:03             0               B82
# 9  6/1/2017 0:03             1               S59
#
#                      OriginName  OriginLat  OriginLong  \
# 0                    4 AV/95 ST  40.616104  -74.031143
# 1     ST GEORGE FERRY/S61 & S91  40.643169  -74.073494
# 2        E 206 ST/BAINBRIDGE AV  40.875008  -73.880142
# 3              TEARDROP/LAYOVER  40.701748  -73.802399
# 4         RIVERDALE AV/W 231 ST  40.881187  -73.909340
# 5                  4 AV/E 10 ST  40.731342  -73.990288
# 6  GERRITSEN AV/GERRITSEN BEACH  40.587101  -73.918503
# 7   GATEWAY CTR TERM/GATEWAY DR  40.652649  -73.877029
# 8   STILLWELL TERMINAL BUS LOOP  40.577080  -73.981293
# 9       RICHMOND TER/PARK AV #3  40.640167  -74.130966
#
#                             DestinationName  DestinationLat  DestinationLong  \
# 0                   BROWNSVILLE ROCKAWAY AV       40.656048       -73.907379
# 1                         S I MALL YUKON AV       40.575935       -74.167686
# 2                          RIVERDALE 263 ST       40.912376       -73.902534
# 3             ROSEDALE LIRR STA via MERRICK       40.666012       -73.735939
# 4           MOTT HAVEN 136 ST via CONCOURSE       40.809654       -73.928360
# 5                 HARLEM 147 ST via MADISON       40.821110       -73.935898
# 6                     MIDWOOD KINGS HWY STA       40.608433       -73.957100
# 7                      BWAY JCT VN SNDRN AV       40.678139       -73.903572
# 8  SPRING CRK TWRS SEAVIEW AV via KINGS HWY       40.642990       -73.878326
# 9                                  HYLAN BL       40.534260       -74.154213
#
#   VehicleRef    ...      ScheduledArrivalTime  Unnamed: 17 expected_date  \
# 0   NYCT_430    ...                  00:06:14          NaN      6/1/2017
# 1  NYCT_8263    ...                  23:58:02          NaN      6/1/2017
# 2  NYCT_4223    ...                  00:00:53          NaN      6/1/2017
# 3  NYCT_8422    ...                  00:03:00          NaN      6/1/2017
# 4  NYCT_4710    ...                  23:59:38          NaN      6/1/2017
# 5  NYCT_3831    ...                  00:02:35          NaN      6/1/2017
# 6  NYCT_4611    ...                  00:08:00          NaN      6/1/2017
# 7  NYCT_4841    ...                  23:58:47          NaN      6/1/2017
# 8  NYCT_6592    ...                  00:00:00          NaN      6/1/2017
# 9  NYCT_8279    ...                  00:01:14          NaN      6/1/2017
#
#    Scheduled_datetime   Expected_datetime             delay  \
# 0 2017-06-01 00:06:14 2017-06-01 00:03:00 -1 days +23:56:46
# 1 2017-05-31 23:58:02 2017-06-01 00:03:00          00:04:58
# 2 2017-06-01 00:00:53 2017-06-01 00:03:00          00:02:07
# 3 2017-06-01 00:03:00 2017-06-01 00:04:00          00:01:00
# 4 2017-05-31 23:59:38 2017-06-01 00:03:00          00:03:22
# 5 2017-06-01 00:02:35 2017-06-01 00:03:00          00:00:25
# 6 2017-06-01 00:08:00 2017-06-01 00:03:00 -1 days +23:55:00
# 7 2017-05-31 23:58:47 2017-06-01 00:04:00          00:05:13
# 8 2017-06-01 00:00:00 2017-06-01 00:03:00          00:03:00
# 9 2017-06-01 00:01:14 2017-06-01 00:03:00          00:01:46
#
#   Scheduled_HourOfDay delay_second delay_minute delay_days
# 0                   0        86206  1436.766667         -1
# 1                  23          298     4.966667          0
# 2                   0          127     2.116667          0
# 3                   0           60     1.000000          0
# 4                  23          202     3.366667          0
# 5                   0           25     0.416667          0
# 6                   0        86100  1435.000000         -1
# 7                  23          313     5.216667          0
# 8                   0          180     3.000000          0
# 9                   0          106     1.766667          0
#
# [10 rows x 26 columns]

# %% [markdown]
# # Data Exploration:

# %% [markdown]
# Next I'm going to explore the data by subsetting the data by the values of the "delay_days" column.

# %%
#getting value_counts for all values for the delay_days column.
df.delay_days.value_counts()
# Out:
#  0        764562
# -1        271111
#  1         12899
# -10075         2
# -17377         1
# Name: delay_days, dtype: int64

# %%
#subsetting the data for those observations where delay_days equals 1
df_DelayDayOne = df[df['delay_days'] == 1]

# %%
df_DelayDayOne.head()
# Out:
#         RecordedAtTime  DirectionRef PublishedLineName            OriginName  \
# 243349  6/1/2017 22:54             1               X10          E 57 ST/3 AV
# 243883  6/1/2017 23:04             0               B61   PROSPECT PK W/18 ST
# 243885  6/1/2017 23:04             0               M57      W 72 ST/BROADWAY
# 243888  6/1/2017 23:04             0           Q44-SBS  MERRICK BL/ARCHER AV
# 243890  6/1/2017 23:04             0               B44    KNAPP ST/SHORE PKY
#
#         OriginLat  OriginLong                           DestinationName  \
# 243349  40.760429  -73.967674  PT RICHMOND via NARROWS RD via GANNON AV
# 243883  40.657639  -73.982887   DOWNTOWN BKLYN FULTON MALL via RED HOOK
# 243885  40.779034  -73.982414              EAST SIDE YORK - 60 ST XTOWN
# 243888  40.704906  -73.793304          SELECT BUS BRONX ZOO via MAIN ST
# 243890  40.585033  -73.931328       WILLAMSBURG BRIDGE PLZ via NOSTRAND
#
#         DestinationLat  DestinationLong VehicleRef    ...      \
# 243349       40.633698       -74.129776  NYCT_2664    ...
# 243883       40.690514       -73.987724   NYCT_774    ...
# 243885       40.759518       -73.959892  NYCT_3820    ...
# 243888       40.842457       -73.877121  NYCT_5912    ...
# 243890       40.709316       -73.959587  NYCT_5045    ...
#
#         ScheduledArrivalTime  Unnamed: 17 expected_date  Scheduled_datetime  \
# 243349              23:02:56          NaN      6/1/2017 2017-05-31 23:02:56
# 243883              23:00:35          NaN      6/1/2017 2017-05-31 23:00:35
# 243885              23:02:22          NaN      6/1/2017 2017-05-31 23:02:22
# 243888              23:03:47          NaN      6/1/2017 2017-05-31 23:03:47
# 243890              23:01:44          NaN      6/1/2017 2017-05-31 23:01:44
#
#          Expected_datetime           delay Scheduled_HourOfDay delay_second  \
# 243349 2017-06-01 23:08:00 1 days 00:05:04                  23          304
# 243883 2017-06-01 23:05:00 1 days 00:04:25                  23          265
# 243885 2017-06-01 23:04:00 1 days 00:01:38                  23           98
# 243888 2017-06-01 23:06:00 1 days 00:02:13                  23          133
# 243890 2017-06-01 23:04:00 1 days 00:02:16                  23          136
#
#        delay_minute delay_days
# 243349     5.066667          1
# 243883     4.416667          1
# 243885     1.633333          1
# 243888     2.216667          1
# 243890     2.266667          1
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Exploring dataframe where "delay_days" equals zero.

# %%
#filtering the original dataset
df_DelayDayZero = df[df['delay_days'] == 0]

# %%
df_DelayDayZero.head()
# Out:
#   RecordedAtTime  DirectionRef PublishedLineName                 OriginName  \
# 1  6/1/2017 0:03             1               S61  ST GEORGE FERRY/S61 & S91
# 2  6/1/2017 0:03             0              Bx10     E 206 ST/BAINBRIDGE AV
# 3  6/1/2017 0:03             0                Q5           TEARDROP/LAYOVER
# 4  6/1/2017 0:03             1               Bx1      RIVERDALE AV/W 231 ST
# 5  6/1/2017 0:03             0                M1               4 AV/E 10 ST
#
#    OriginLat  OriginLong                  DestinationName  DestinationLat  \
# 1  40.643169  -74.073494                S I MALL YUKON AV       40.575935
# 2  40.875008  -73.880142                 RIVERDALE 263 ST       40.912376
# 3  40.701748  -73.802399    ROSEDALE LIRR STA via MERRICK       40.666012
# 4  40.881187  -73.909340  MOTT HAVEN 136 ST via CONCOURSE       40.809654
# 5  40.731342  -73.990288        HARLEM 147 ST via MADISON       40.821110
#
#    DestinationLong VehicleRef    ...      ScheduledArrivalTime  Unnamed: 17  \
# 1       -74.167686  NYCT_8263    ...                  23:58:02          NaN
# 2       -73.902534  NYCT_4223    ...                  00:00:53          NaN
# 3       -73.735939  NYCT_8422    ...                  00:03:00          NaN
# 4       -73.928360  NYCT_4710    ...                  23:59:38          NaN
# 5       -73.935898  NYCT_3831    ...                  00:02:35          NaN
#
#   expected_date  Scheduled_datetime   Expected_datetime    delay  \
# 1      6/1/2017 2017-05-31 23:58:02 2017-06-01 00:03:00 00:04:58
# 2      6/1/2017 2017-06-01 00:00:53 2017-06-01 00:03:00 00:02:07
# 3      6/1/2017 2017-06-01 00:03:00 2017-06-01 00:04:00 00:01:00
# 4      6/1/2017 2017-05-31 23:59:38 2017-06-01 00:03:00 00:03:22
# 5      6/1/2017 2017-06-01 00:02:35 2017-06-01 00:03:00 00:00:25
#
#   Scheduled_HourOfDay delay_second delay_minute delay_days
# 1                  23          298     4.966667          0
# 2                   0          127     2.116667          0
# 3                   0           60     1.000000          0
# 4                  23          202     3.366667          0
# 5                   0           25     0.416667          0
#
# [5 rows x 26 columns]

# %%
#value counts of the dates in scheduled datetime
df_DelayDayZero.Scheduled_datetime.dt.date.value_counts()
# Out:
# 2017-06-02    187562
# 2017-06-01    176890
# 2017-06-05    161573
# 2017-06-03    132538
# 2017-06-04    104490
# 2017-05-31      1509
# Name: Scheduled_datetime, dtype: int64

# %%
#value_counts of the dates in Expected datetime
df_DelayDayZero.Expected_datetime.dt.date.value_counts()
# Out:
# 2017-06-02    187434
# 2017-06-01    177178
# 2017-06-05    162137
# 2017-06-03    132419
# 2017-06-04    105394
# Name: Expected_datetime, dtype: int64

# %%
df_DelayDayZero.delay.value_counts()
# Out:
# 00:01:00    21215
# 00:00:00    20973
# 00:02:00    19748
# 00:03:00    17457
# 00:04:00    15582
# 00:05:00    13712
# 00:06:00    12310
# 00:07:00    10952
# 00:08:00     9878
# 00:09:00     8917
# 00:10:00     7993
# 00:11:00     7055
# 00:12:00     6291
# 00:13:00     5477
# 00:14:00     4953
# 00:15:00     4187
# 00:16:00     3671
# 00:17:00     3111
# 00:18:00     2872
# 00:19:00     2403
# 00:12:02     2121
# 00:20:00     2113
# 00:21:00     1884
# 00:06:40     1718
# 00:22:00     1661
# 00:22:12     1582
# 00:36:00     1567
# 00:23:00     1519
# 00:24:00     1402
# 00:00:52     1230
#             ...
# 01:04:49        1
# 23:55:07        1
# 01:03:37        1
# 03:13:00        1
# 00:55:18        1
# 23:25:00        1
# 23:55:37        1
# 23:30:47        1
# 01:09:54        1
# 01:14:38        1
# 01:21:54        1
# 00:54:09        1
# 00:57:12        1
# 23:52:43        1
# 01:34:00        1
# 00:47:03        1
# 01:45:00        1
# 00:53:34        1
# 23:55:14        1
# 01:11:58        1
# 01:20:05        1
# 23:32:43        1
# 23:54:23        1
# 01:10:36        1
# 23:45:26        1
# 01:49:10        1
# 01:12:19        1
# 01:15:57        1
# 00:53:56        1
# 01:02:36        1
# Name: delay, Length: 5025, dtype: int64

# %%
df_DelayDayZero.delay_minute.value_counts()
# Out:
# 1.000000       21215
# 0.000000       20973
# 2.000000       19748
# 3.000000       17457
# 4.000000       15582
# 5.000000       13712
# 6.000000       12310
# 7.000000       10952
# 8.000000        9878
# 9.000000        8917
# 10.000000       7993
# 11.000000       7055
# 12.000000       6291
# 13.000000       5477
# 14.000000       4953
# 15.000000       4187
# 16.000000       3671
# 17.000000       3111
# 18.000000       2872
# 19.000000       2403
# 12.033333       2121
# 20.000000       2113
# 21.000000       1884
# 6.666667        1718
# 22.000000       1661
# 22.200000       1582
# 36.000000       1567
# 23.000000       1519
# 24.000000       1402
# 0.533333        1230
#                ...
# 1432.166667        1
# 119.566667         1
# 51.216667          1
# 1409.516667        1
# 1424.783333        1
# 63.383333          1
# 1436.966667        1
# 1434.716667        1
# 1432.233333        1
# 1433.733333        1
# 1432.966667        1
# 1432.716667        1
# 1432.466667        1
# 1430.283333        1
# 69.666667          1
# 1433.216667        1
# 1412.716667        1
# 1434.983333        1
# 1419.533333        1
# 1419.783333        1
# 1434.483333        1
# 65.250000          1
# 1420.283333        1
# 1436.016667        1
# 1435.233333        1
# 107.850000         1
# 1422.716667        1
# 72.733333          1
# 55.650000          1
# 59.733333          1
# Name: delay_minute, Length: 5025, dtype: int64

# %% [markdown]
# #### Exploring the dataset where "delay_days" equals -1.

# %%
#filtering the original dataset for only those observations where 'delay_days' equals -1
df_DelayDay_neg1 = df[df['delay_days'] == -1]

# %%
df_DelayDay_neg1.head()
# Out:
#    RecordedAtTime  DirectionRef PublishedLineName  \
# 0   6/1/2017 0:03             0                B8
# 6   6/1/2017 0:03             0               B31
# 11  6/1/2017 0:03             1                B1
# 12  6/1/2017 0:03             1               B26
# 13  6/1/2017 0:03             0              Bx39
#
#                       OriginName  OriginLat  OriginLong  \
# 0                     4 AV/95 ST  40.616104  -74.031143
# 6   GERRITSEN AV/GERRITSEN BEACH  40.587101  -73.918503
# 11                    87 ST/4 Av  40.621925  -74.028496
# 12        WYCKOFF ST/PALMETTO ST  40.699150  -73.910477
# 13      SOUNDVIEW AV/STEPHENS AV  40.807869  -73.852715
#
#                       DestinationName  DestinationLat  DestinationLong  \
# 0             BROWNSVILLE ROCKAWAY AV       40.656048       -73.907379
# 6               MIDWOOD KINGS HWY STA       40.608433       -73.957100
# 11       MANHATTAN BEACH KINGSBORO CC       40.578094       -73.940170
# 12  DNTWN BKLYN TILLARY ST via HALSEY       40.693939       -73.990311
# 13  WAKEFIELD 241 ST via WHITE PLS RD       40.903309       -73.849922
#
#    VehicleRef    ...      ScheduledArrivalTime  Unnamed: 17 expected_date  \
# 0    NYCT_430    ...                  00:06:14          NaN      6/1/2017
# 6   NYCT_4611    ...                  00:08:00          NaN      6/1/2017
# 11  NYCT_7141    ...                  00:05:55          NaN      6/1/2017
# 12  NYCT_6503    ...                  00:05:55          NaN      6/1/2017
# 13  NYCT_4723    ...                  00:04:12          NaN      6/1/2017
#
#     Scheduled_datetime   Expected_datetime             delay  \
# 0  2017-06-01 00:06:14 2017-06-01 00:03:00 -1 days +23:56:46
# 6  2017-06-01 00:08:00 2017-06-01 00:03:00 -1 days +23:55:00
# 11 2017-06-01 00:05:55 2017-06-01 00:03:00 -1 days +23:57:05
# 12 2017-06-01 00:05:55 2017-06-01 00:03:00 -1 days +23:57:05
# 13 2017-06-01 00:04:12 2017-06-01 00:04:00 -1 days +23:59:48
#
#    Scheduled_HourOfDay delay_second delay_minute delay_days
# 0                    0        86206  1436.766667         -1
# 6                    0        86100  1435.000000         -1
# 11                   0        86225  1437.083333         -1
# 12                   0        86225  1437.083333         -1
# 13                   0        86388  1439.800000         -1
#
# [5 rows x 26 columns]

# %%
df_DelayDay_neg1.shape
# Out:
# (271111, 26)

# %%
#calculating the time difference according to minutes
df_DelayDay_neg1['neg1_minute_diff'] = df_DelayDay_neg1['Expected_datetime'].dt.minute - df_DelayDay_neg1['Scheduled_datetime'].dt.minute
# Out:
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#creating a new feature "neg1_minute_diff" to account for the minute differences.
print(df_DelayDay_neg1.neg1_minute_diff.value_counts())
# Out:
# -1     70133
#  0     64714
# -2     48293
# -3     28850
# -4     15888
# -5      9125
# -6      5552
# -7      3716
# -8      2547
# -9      1955
#  58     1789
# -10     1599
#  57     1587
#  59     1478
#  56     1330
# -11     1191
# -12      944
#  55      939
# -13      712
#  54      704
# -14      582
# -15      532
#  53      505
# -16      400
#  52      357
#  51      355
#  50      323
#  49      292
# -18      284
# -17      282
#        ...
#  23        8
#  13        8
#  10        7
#  11        7
#  16        7
#  2         6
# -41        6
#  9         5
#  6         5
#  1         5
# -40        5
# -50        5
#  8         4
# -44        4
# -42        4
# -51        3
# -47        2
# -46        2
# -45        2
#  3         2
#  7         2
# -43        2
# -55        2
# -48        2
# -58        1
# -52        1
# -49        1
#  4         1
# -54        1
# -57        1
# Name: neg1_minute_diff, Length: 115, dtype: int64

# %% [markdown]
# There are some instances in the neg1_minute_diff column of df_DelayDay_neg1 where the minute difference is negative, suggesting that that bus arrived on time.  We can check this assumption by exploring the Scheduled_datetime and Expected_datetime columns of the df_DelayDay_neg1 columns.

# %%
#value counts of the dates in scheduled datetime
df_DelayDay_neg1.Scheduled_datetime.dt.date.value_counts()
# Out:
# 2017-06-05    70583
# 2017-06-01    68350
# 2017-06-02    59908
# 2017-06-03    38425
# 2017-06-04    33845
# Name: Scheduled_datetime, dtype: int64

# %%
#value counts of the dates in Expected datetime
df_DelayDay_neg1.Expected_datetime.dt.date.value_counts()
# Out:
# 2017-06-05    70583
# 2017-06-01    68350
# 2017-06-02    59908
# 2017-06-03    38425
# 2017-06-04    33845
# Name: Expected_datetime, dtype: int64

# %% [markdown]
# The dataset has observations recorded over a five day period from June 1, 2017 to June 5, 2017.  Because the value_counts in "Scheduled_datetime" and "Expected_datetime" of the df_DelayDay_neg1 dataframe are equal for each date, we can safely assume that the negative numbers "neg1_minute_diff" column from df_DelayDay_neg1 represent those buses that arrived before their scheduled time.

# %% [markdown]
# Out of all the buses that arrived before their scheduled time, the majority of them were early by five to six minutes or less.  Some buses arrived more than six minutes before their time, but I dropped those observations because they totaled only a few thousand all together and represented less than 1% of the total data.

# %%
#filtering the df_DelayDay_neg1 dataframe for only those observations where the value of 'neg1_minute_diff' is  greater than -5
df_DelayDay_neg1 = df_DelayDay_neg1[df_DelayDay_neg1['neg1_minute_diff'] > -5]

# %%
#re assigning the values of delay_minute column, according to the time difference in the column 'neg1_minute_diff'.  For 
#observations where "neg1_minute_diff" was less than or equal to five, I set the value of 'delay_minute for that observation
#to zero.If 'neg1_minute_diff' is greater than 5 for an observation, I assigned the value of 'delay_minute'
#a random number greater than 5 (I chose 6) which would represent a delay and that observation would be classified
#as not on time (see cell 49 below).

df_DelayDay_neg1.loc[(df_DelayDay_neg1['neg1_minute_diff'] <= 5), 'delay_minute'] = 0
df_DelayDay_neg1.loc[(df_DelayDay_neg1['neg1_minute_diff'] > 5), 'delay_minute'] = 6

# %%
df_DelayDay_neg1.delay_minute.value_counts()
# Out:
# 0.0    227900
# 6.0     12070
# Name: delay_minute, dtype: int64

# %%
#dropping the 'neg1_minute_diff' column from df_neg1
df_DelayDay_neg1 = df_DelayDay_neg1.drop('neg1_minute_diff', 1)

# %%
df_DelayDay_neg1.head()
# Out:
#    RecordedAtTime  DirectionRef PublishedLineName  \
# 0   6/1/2017 0:03             0                B8
# 11  6/1/2017 0:03             1                B1
# 12  6/1/2017 0:03             1               B26
# 13  6/1/2017 0:03             0              Bx39
# 15  6/1/2017 0:03             1              Bx31
#
#                      OriginName  OriginLat  OriginLong  \
# 0                    4 AV/95 ST  40.616104  -74.031143
# 11                   87 ST/4 Av  40.621925  -74.028496
# 12       WYCKOFF ST/PALMETTO ST  40.699150  -73.910477
# 13     SOUNDVIEW AV/STEPHENS AV  40.807869  -73.852715
# 15  VAN CORTLANDT PK E/E 242 ST  40.902660  -73.868378
#
#                       DestinationName  DestinationLat  DestinationLong  \
# 0             BROWNSVILLE ROCKAWAY AV       40.656048       -73.907379
# 11       MANHATTAN BEACH KINGSBORO CC       40.578094       -73.940170
# 12  DNTWN BKLYN TILLARY ST via HALSEY       40.693939       -73.990311
# 13  WAKEFIELD 241 ST via WHITE PLS RD       40.903309       -73.849922
# 15                     WESTCHESTER SQ       40.841076       -73.842850
#
#    VehicleRef    ...      ScheduledArrivalTime  Unnamed: 17 expected_date  \
# 0    NYCT_430    ...                  00:06:14          NaN      6/1/2017
# 11  NYCT_7141    ...                  00:05:55          NaN      6/1/2017
# 12  NYCT_6503    ...                  00:05:55          NaN      6/1/2017
# 13  NYCT_4723    ...                  00:04:12          NaN      6/1/2017
# 15   NYCT_274    ...                  00:05:00          NaN      6/1/2017
#
#     Scheduled_datetime   Expected_datetime             delay  \
# 0  2017-06-01 00:06:14 2017-06-01 00:03:00 -1 days +23:56:46
# 11 2017-06-01 00:05:55 2017-06-01 00:03:00 -1 days +23:57:05
# 12 2017-06-01 00:05:55 2017-06-01 00:03:00 -1 days +23:57:05
# 13 2017-06-01 00:04:12 2017-06-01 00:04:00 -1 days +23:59:48
# 15 2017-06-01 00:05:00 2017-06-01 00:03:00 -1 days +23:58:00
#
#    Scheduled_HourOfDay delay_second delay_minute delay_days
# 0                    0        86206          0.0         -1
# 11                   0        86225          0.0         -1
# 12                   0        86225          0.0         -1
# 13                   0        86388          0.0         -1
# 15                   0        86280          0.0         -1
#
# [5 rows x 26 columns]

# %%
#Getting the shape of df_DelayDayZero and df_DelayDay_neg1
print(df_DelayDayZero.shape)
print()
print(df_DelayDay_neg1.shape)
# Out:
# (764562, 26)
#
# (239970, 26)

# %%
#joining df_DelayDayZero and df_DelayDay_neg1 into one dataframe called df
df = pd.concat([df_DelayDayZero, df_DelayDay_neg1], axis=0, ignore_index=True)

# %%
#getting the shape of the concatenated dataframe, df
print(df.shape)
# Out:
# (1004532, 26)

# %%
df.delay_days.value_counts()
# Out:
#  0    764562
# -1    239970
# Name: delay_days, dtype: int64

# %%
#creating source and destination features to help calculate distance between each origin and destination.
df["source"] = [(i, j) for i, j in zip(df["OriginLat"], df["OriginLong"])]

df["destination"] = [(i, j) for i, j in zip(df["DestinationLat"], df["DestinationLong"])]

#creating feature 'dist' to calculate the distance between origin and destination.
df["dist"] = [geopy.distance.distance(i, j).km for i, j in zip(df["source"], df["destination"])]

# %%
#creating features to measure distance between vehicle and destination.
df['Vehicle_location2'] = [(i,j) for i, j in zip(df['VehicleLocation.Latitude'], df['VehicleLocation.Longitude'])]
df["VehicleToDestination"] = [geopy.distance.distance(i, j).km for i, j in zip(df["Vehicle_location2"], df["destination"])]

# %%
#creating output variable by defining "on_time" as those buses that arrived five minutes or less than their scheduled time.
df['on_time'] = np.where((df['delay_minute'] > 5) | (df['delay_minute'] < -1), 0, 1)

# %%
#getting value count for binary output variable
df['on_time'].value_counts()
# Out:
# 1    605330
# 0    399202
# Name: on_time, dtype: int64

# %%
# Resampling our data

# Class count
count_class_1, count_class_0 = df.on_time.value_counts()
print(count_class_1)
print(count_class_0)
# Divide by class
df_class_0 = df[df['on_time'] == 0]
df_class_1 = df[df['on_time'] == 1]
# Out:
# 605330
# 399202

# %%
#extract the observations with class zero, equal to the number of obervations equal
df_class_1_under = df_class_1.sample(count_class_0)

#create a new dataframe with the same number of values for our two classes
df_resampled = pd.concat([df_class_1_under, df_class_0], axis=0, ignore_index=True)

print('Random under-sampling:')
print(df_resampled.on_time.value_counts())

df_resampled.on_time.value_counts().plot(kind='bar', title='Count (target)')
# Out:
# Random under-sampling:
# 1    399202
# 0    399202
# Name: on_time, dtype: int64

# %%
#shuffling the data to make it completely random, after resampling
from sklearn.utils import shuffle 
df_resampled = shuffle(df_resampled)

#resetting index
df_resampled = df_resampled.reset_index(drop=True)

# %%
df_resampled.head()
# Out:
#    RecordedAtTime  DirectionRef PublishedLineName               OriginName  \
# 0  6/2/2017 17:46             0               M98             3 AV/E 67 ST
# 1  6/1/2017 11:04             0                B3          25 AV/HARWAY AV
# 2  6/1/2017 13:44             0               M42              12 AV/42 ST
# 3  6/3/2017 10:47             0               B64  STILLWELL AV/MERMAID AV
# 4  6/5/2017 19:31             1               B35    HEGEMAN AV/CHESTER AV
#
#    OriginLat  OriginLong                           DestinationName  \
# 0  40.767117  -73.962448  LTD WASHINGTON HTS CABRINI BLVD via 3 AV
# 1  40.593021  -73.992180               BERGEN BCH E 71 ST via AV U
# 2  40.762150  -74.001442                       UN - 1 AV CROSSTOWN
# 3  40.577091  -73.981636  BAY RIDGE SHORE RD via 13 AV via BAY RDG
# 4  40.656216  -73.908150                 McDONALD AV via CHURCH AV
#
#    DestinationLat  DestinationLong VehicleRef   ...    Scheduled_HourOfDay  \
# 0       40.859013       -73.934250  NYCT_3954   ...                     17
# 1       40.619881       -73.907265  NYCT_5088   ...                     11
# 2       40.748005       -73.969803  NYCT_3927   ...                     13
# 3       40.637070       -74.036087  NYCT_7163   ...                     10
# 4       40.642696       -73.979881   NYCT_233   ...                     19
#
#    delay_second delay_minute delay_days                            source  \
# 0          1522    25.366667          0           (40.767117, -73.962448)
# 1         86271     0.000000         -1            (40.593021, -73.99218)
# 2         86273     0.000000         -1            (40.76215, -74.001442)
# 3          1021    17.016667          0  (40.577090999999996, -73.981636)
# 4           540     9.000000          0            (40.656216, -73.90815)
#
#                destination       dist  \
# 0   (40.859013, -73.93425)  10.478735
# 1  (40.619881, -73.907265)   7.781045
# 2  (40.748005, -73.969803)   3.099323
# 3   (40.63707, -74.036087)   8.099282
# 4  (40.642696, -73.979881)   6.249968
#
#                           Vehicle_location2 VehicleToDestination on_time
# 0                   (40.848817, -73.936638)             1.150042       0
# 1  (40.598704999999995, -73.95755799999999)             4.862686       1
# 2                   (40.758882, -73.993711)             2.352714       1
# 3                   (40.636687, -74.034487)             0.141877       0
# 4                   (40.652456, -73.922332)             4.986796       0
#
# [5 rows x 32 columns]

# %%
df_resampled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798404 entries, 0 to 798403
# Data columns (total 32 columns):
# RecordedAtTime               798404 non-null object
# DirectionRef                 798404 non-null int64
# PublishedLineName            798404 non-null object
# OriginName                   798404 non-null object
# OriginLat                    798404 non-null float64
# OriginLong                   798404 non-null float64
# DestinationName              798404 non-null object
# DestinationLat               798404 non-null float64
# DestinationLong              798404 non-null float64
# VehicleRef                   798404 non-null object
# VehicleLocation.Latitude     798404 non-null float64
# VehicleLocation.Longitude    798404 non-null float64
# NextStopPointName            798404 non-null object
# ArrivalProximityText         798404 non-null object
# DistanceFromStop             798404 non-null object
# ExpectedArrivalTime          798404 non-null object
# ScheduledArrivalTime         798404 non-null object
# Unnamed: 17                  44 non-null object
# expected_date                798404 non-null object
# Scheduled_datetime           798404 non-null datetime64[ns]
# Expected_datetime            798404 non-null datetime64[ns]
# delay                        798404 non-null timedelta64[ns]
# Scheduled_HourOfDay          798404 non-null int64
# delay_second                 798404 non-null int64
# delay_minute                 798404 non-null float64
# delay_days                   798404 non-null int64
# source                       798404 non-null object
# destination                  798404 non-null object
# dist                         798404 non-null float64
# Vehicle_location2            798404 non-null object
# VehicleToDestination         798404 non-null float64
# on_time                      798404 non-null int32
# dtypes: datetime64[ns](2), float64(9), int32(1), int64(4), object(15), timedelta64[ns](1)
# memory usage: 191.9+ MB

# %%
#getting the average of all numeric variables by grouping the data by the output variable
df_resampled.groupby('on_time').mean()
# Out:
#          DirectionRef  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# on_time
# 0            0.516941  40.735675  -73.932254       40.729343       -73.934197
# 1            0.495834  40.726329  -73.929561       40.728021       -73.928854
#
#          VehicleLocation.Latitude  VehicleLocation.Longitude  \
# on_time
# 0                       40.731780                 -73.932329
# 1                       40.726282                 -73.928722
#
#          Scheduled_HourOfDay  delay_second  delay_minute  delay_days  \
# on_time
# 0                  13.943547   4321.042390     28.899934   -0.030235
# 1                  12.266632  32580.803107      1.394951   -0.376589
#
#              dist  VehicleToDestination
# on_time
# 0        9.689733              4.034128
# 1        8.976535              4.981361

# %%
#creating two subsets of the dataframe to explore the data according to the different values of our binary output variable.
df_NotOntime = df_resampled[df_resampled['on_time'] == 0]
df_Ontime = df_resampled[df_resampled['on_time'] == 1]

# %%
#getting the total number of unique bus line names in the PublishedLineName column
df_resampled.PublishedLineName.describe()
# Out:
# count     798404
# unique       305
# top           B6
# freq       14346
# Name: PublishedLineName, dtype: object

# %%
#Using the subset of the data for the buses that did not make it on time, and getting the total number of unique bus line
#names in this subset of the data.
df_NotOntime.PublishedLineName.describe()
# Out:
# count     399202
# unique       305
# top          B41
# freq        7546
# Name: PublishedLineName, dtype: object

# %%
#Using the subset of the data for the buses that did make it on time, and getting the total number of unique bus line 
#names in this subset of the data
df_Ontime.PublishedLineName.describe()
# Out:
# count     399202
# unique       236
# top           B6
# freq        8593
# Name: PublishedLineName, dtype: object

# %% [markdown]
# There are 69 Bus lines that never made it on time to their destination.

# %%
notontime = df_NotOntime.PublishedLineName
ontime = df_Ontime.PublishedLineName

# %%
#identifying the PublishedLineName that were never on time.
intersect = np.intersect1d(notontime, ontime)
difference1 = np.setdiff1d(notontime, intersect)
#difference2 = np.setdiff1d(ontime, intersect)

# %%
#creating a new dataframe with the bus lines in PublishedLineName that were never on time.
df_LinesLate = df_resampled[df_resampled.PublishedLineName.isin(difference1)]
df_LinesLate.head()
# Out:
#       RecordedAtTime  DirectionRef PublishedLineName  \
# 1270  6/1/2017 14:23             1               Q10
# 1312  6/1/2017 14:23             1               Q72
# 1796  6/3/2017 18:07             0             BxM11
# 1834  6/3/2017 18:07             0                Q8
# 3307  6/4/2017 17:49             1               QM5
#
#                           OriginName  OriginLat  OriginLong  \
# 1270  FT GEORGE AV/66 FORT GEORGE AV  40.858330  -73.925385
# 1312  FT GEORGE AV/66 FORT GEORGE AV  40.858330  -73.925385
# 1796             CENTRAL PARK S/6 AV  40.766315  -73.977493
# 1834             CENTRAL PARK S/6 AV  40.766315  -73.977493
# 3307      ELTINGVILLE/TRANSIT CENTER  40.560760  -74.171089
#
#                                         DestinationName  DestinationLat  \
# 1270  JFK AIRPORT CENTRAL TERMINAL via LEFFERTS BL v...       40.647278
# 1312          REGO PARK 63 DR-QUEENS BL via JUNCTION BL       40.647278
# 1796  WAKEFIELD 241 ST via BRONX ZOO via WHITE PLAIN...       40.631992
# 1834                     JAMAICA 165 ST TERM via 101 AV       40.875988
# 3307                             MIDTOWN 57 ST via 6 AV       40.647278
#
#       DestinationLong  VehicleRef   ...    Scheduled_HourOfDay  delay_second  \
# 1270       -73.779633  MTABC_5390   ...                     14           722
# 1312       -73.779633  MTABC_3615   ...                     14           782
# 1796       -73.946701  MTABC_3357   ...                     17          1332
# 1834       -73.829735  MTABC_3742   ...                     17          1332
# 3307       -73.779633  MTABC_3203   ...                     17          2160
#
#      delay_minute delay_days                                    source  \
# 1270    12.033333          0            (40.85833, -73.92538499999999)
# 1312    13.033333          0            (40.85833, -73.92538499999999)
# 1796    22.200000          0  (40.766315000000006, -73.97749300000001)
# 1834    22.200000          0  (40.766315000000006, -73.97749300000001)
# 3307    36.000000          0          (40.560759999999995, -74.171089)
#
#                           destination       dist  \
# 1270  (40.647278, -73.77963299999999)  26.472627
# 1312  (40.647278, -73.77963299999999)  26.472627
# 1796          (40.631992, -73.946701)  15.141634
# 1834          (40.875988, -73.829735)  17.427408
# 3307  (40.647278, -73.77963299999999)  34.496387
#
#                              Vehicle_location2 VehicleToDestination on_time
# 1270           (40.706521, -73.83181400000001)             7.921049       0
# 1312  (40.748909000000005, -73.86925600000001)            13.592238       0
# 1796          (40.755790000000005, -73.977106)            13.985665       0
# 1834           (40.704724, -73.79678100000001)            19.221142       0
# 3307                   (40.742671, -73.753575)            10.819743       0
#
# [5 rows x 32 columns]

# %%
df_LinesLate.PublishedLineName.describe()
# Out:
# count     1451
# unique      69
# top        Q53
# freq        69
# Name: PublishedLineName, dtype: object

# %%
#making two scatter plots to show the Origin locations of buses on time, and not on time, using Origin latitude 
#and Origin longitude

#setting figure size
f = plt.figure(figsize=(20,10))

#making a plot figure that will have one row with two plots in each row
f.add_subplot(1, 2, 1)
sns.scatterplot(x=df_LinesLate.OriginLat, y=df_LinesLate.OriginLong)
plt.title("Origin Locations for Bus Lines Not On Time")
plt.ylabel('Longitude')
plt.xlabel('Latitude')

f.add_subplot(1, 2, 2)
sns.scatterplot(x=df_LinesLate.DestinationLat, y=df_LinesLate.DestinationLong)
plt.title('Destination Locations for Bus Lines Not On Time')
plt.ylabel('Longitude')
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# This is interesting.  The bus lines that were never on time always originated from four particular locations: 40.56 and -74.18 (staten island), 40.77 and -73.97 (upper east side of manhattan), 40.86 and -73.92 (Bronx, near Yankee stadium and the Bronx zoo) , and 40.81 and -73.82 (near the east river)

# %%
#making two scatter plots to show the Origin locations of buses on time, and not on time, using Origin latitude 
#and Origin longitude

#setting figure size
f = plt.figure(figsize=(20,10))

#making a plot figure that will have one row with two plots in each row
f.add_subplot(1, 2, 1)
sns.scatterplot(x=df_NotOntime.OriginLat, y=df_NotOntime.OriginLong)
plt.title("Origin Locations for buses Not On Time")
plt.ylabel('Longitude')
plt.xlabel('Latitude')

f.add_subplot(1, 2, 2)
sns.scatterplot(x=df_Ontime.OriginLat, y=df_Ontime.OriginLong)
plt.title('Origin Locations for buses On Time')
plt.ylabel('Longitude')
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %%
#making two scatter plots to show the Destination locations of buses on time, and not on time, using Destination latitude 
#and Destination longitude

#setting figure size
f = plt.figure(figsize=(20,10))

#making a plot figure that will have one row with two plots in each row
f.add_subplot(1, 2, 1)
sns.scatterplot(x=df_NotOntime.DestinationLat, y=df_NotOntime.DestinationLong)
plt.title("Destination Locations for buses Not On Time")
plt.ylabel('Longitude')
plt.xlabel('Latitude')

f.add_subplot(1, 2, 2)
sns.scatterplot(x=df_Ontime.DestinationLat, y=df_Ontime.DestinationLong)
plt.title('Destination Locations for buses On Time')
plt.ylabel('Longitude')
plt.xlabel('Latitude')

#hue=df_NotOntime.PublishedLineName[:15]
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# The two sets of scatterplot show the origin locations and destination locations using latitude and longitude for all buses, on time and those not on time, from the dataset.  As you can see, they are near identical for both scenarios, meaning that both scenarios have many common locations between them, and that location in and of itself is not the sole reason for a bus to be on time or not on time.
#
# The box plots below show, show the scheduled hours of arrival for each bus stop.  On the left we have "Scheduled Hours of the day for buses Not On Time", and on the right we have "Scheduled Hours of the day for buses On Time".  As we can see, the median hour for the buses not on time is about 15, which is closer to the late afternoon rush hours.  But the median hour for the buses on time is closer to twelve, which is not close to either the morning or late afternoon rush hours.
#
# Also something important to note is that for those buses that are not on time, the first quartile (25% of the instances) is at about hour number eleven, which is significantly higher than the first quartile for those buses that were on time, which is at hour number eight.  This may suggest that for those buses that were not on time, the average hour is higher and closer to the later hours in the afternoon when there is probably more traffic on the road versus the average hour for those buses that were on time.
#
# This insight may provide support for the idea that traffic is the differentiating factor on whether or not a bus is on time.

# %%
#Making a boxplot for the Scheduled_HourOfDay column for both subsets of our data, df_Ontime and df_NotOntime.

#setting figure size
f = plt.figure(figsize=(20,10))

#making a plot figure that will have one row with two plots in each row
f.add_subplot(1, 2, 1)
sns.boxplot(x=df_NotOntime.on_time, y=df_NotOntime.Scheduled_HourOfDay, data=df_NotOntime)
plt.title("Scheduled Hours of the day for buses Not On Time")


f.add_subplot(1, 2, 2)
sns.boxplot(x=df_Ontime.on_time, y=df_Ontime.Scheduled_HourOfDay, data=df_Ontime)
plt.title("Scheduled Hours of the day for buses On Time")
# Out:
# Text(0.5, 1.0, 'Scheduled Hours of the day for buses On Time')

# %%
#plotting the "Scheduled_HoursOfDay" for the binary values of output variable "on time"
plt.figure(figsize=(40,20))
pd.crosstab(df_resampled.Scheduled_HourOfDay,df_resampled.on_time).plot(kind='bar')
plt.title('Frequency for Scheduled Hours of Day')
plt.xlabel('Scheduled_HourOfDay')
plt.ylabel('Frequency of each hour')
plt.show()

# %%
#squaring "dist" and "VehicleToDestination" variables.
df_resampled['dist_squared'] = df_resampled['dist'] ** 2
df_resampled['VehicleToDestination_squared'] = df_resampled['VehicleToDestination'] ** 2

# %%
df_resampled.columns
# Out:
# Index(['RecordedAtTime', 'DirectionRef', 'PublishedLineName', 'OriginName',
#        'OriginLat', 'OriginLong', 'DestinationName', 'DestinationLat',
#        'DestinationLong', 'VehicleRef', 'VehicleLocation.Latitude',
#        'VehicleLocation.Longitude', 'NextStopPointName',
#        'ArrivalProximityText', 'DistanceFromStop', 'ExpectedArrivalTime',
#        'ScheduledArrivalTime', 'Unnamed: 17', 'expected_date',
#        'Scheduled_datetime', 'Expected_datetime', 'delay',
#        'Scheduled_HourOfDay', 'delay_second', 'delay_minute', 'delay_days',
#        'source', 'destination', 'dist', 'Vehicle_location2',
#        'VehicleToDestination', 'on_time', 'dist_squared',
#        'VehicleToDestination_squared'],
#       dtype='object')

# %%
#dropping some columns and creating the dataframe with the independent variables
df_X = df_resampled.drop(['RecordedAtTime', 'ArrivalProximityText', 'Unnamed: 17', 'PublishedLineName', 'VehicleRef', 
                 'NextStopPointName', 'ExpectedArrivalTime', 'ScheduledArrivalTime', 'on_time', 'OriginName', 
                 'DestinationName','source', 'destination', 'Vehicle_location2', 'DistanceFromStop', 'Scheduled_datetime', 
                 'Expected_datetime', 'delay', 'delay_second', 'delay_minute', 'delay_days', 'source', 
                 'destination', 'expected_date', 'dist_squared', 'VehicleToDestination_squared'], 1)

#creating dataframe of the independent (predictor) values
#XD_df = pd.get_dummies(X, columns=['OriginName', 'DestinationName'])


Y = df_resampled['on_time']

# %%
#examining the dataframe with the predictor variables
df_X.head()
# Out:
#    DirectionRef  OriginLat  OriginLong  DestinationLat  DestinationLong  \
# 0             0  40.767117  -73.962448       40.859013       -73.934250
# 1             0  40.593021  -73.992180       40.619881       -73.907265
# 2             0  40.762150  -74.001442       40.748005       -73.969803
# 3             0  40.577091  -73.981636       40.637070       -74.036087
# 4             1  40.656216  -73.908150       40.642696       -73.979881
#
#    VehicleLocation.Latitude  VehicleLocation.Longitude  Scheduled_HourOfDay  \
# 0                 40.848817                 -73.936638                   17
# 1                 40.598705                 -73.957558                   11
# 2                 40.758882                 -73.993711                   13
# 3                 40.636687                 -74.034487                   10
# 4                 40.652456                 -73.922332                   19
#
#         dist  VehicleToDestination
# 0  10.478735              1.150042
# 1   7.781045              4.862686
# 2   3.099323              2.352714
# 3   8.099282              0.141877
# 4   6.249968              4.986796

# %%
#Creating a heatmap to check for any correlation between our independent variables.
Xvar_heatmap = sns.heatmap(df_X.corr(), vmin=-1, vmax=1)

print(Xvar_heatmap)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
#checking shape of X
df_X.shape
# Out:
# (798404, 10)

# %%
#checking which column has NaN value
df_X.isnull().sum().sum()
# Out:
# 0

# %%
#checking the shape of outcome variable Y.
Y.shape
# Out:
# (798404,)

# %%
#creating initial train_test_split, before PCA
train_X, test_X, train_Y, test_Y = train_test_split(df_X, Y, test_size=.25)
print(test_X.shape)
print(test_Y.shape)

#checking for any NaN values in our data.
#print(np.isnan(train_Y).any())
#print(np.isnan(train_X).any().sum())
#print(np.isnan(test_Y).any())
#print(np.isnan(test_X).any().sum())
# Out:
# (199601, 10)
# (199601,)

# %%
#creating a smaller dataset with full features

df_X_FullDataSmall = df_X.iloc[:150000, :]
print(df_X_FullDataSmall.shape)

#getting a smaller sample set for output variable Y 
Y_FullDataSmall = Y[:150000]
print(Y_FullDataSmall.shape)
# Out:
# (150000, 10)
# (150000,)

# %%
#creating a second train_test_split, using small dataset with full features
train_X_FullDataSmall, test_X_FullDataSmall, train_Y_FullDataSmall, test_Y_FullDataSmall = train_test_split(df_X_FullDataSmall, Y_FullDataSmall, test_size=.25)
print(test_X_FullDataSmall.shape)
print(test_Y_FullDataSmall.shape)

#checking for any NaN values in our data.
#print(np.isnan(train_Y).any())
#print(np.isnan(train_X).any().sum())
#print(np.isnan(test_Y).any())
#print(np.isnan(test_X).any().sum())
# Out:
# (37500, 10)
# (37500,)

# %%
# Create the first model by Initializing and training the decision tree
decision_tree = tree.DecisionTreeClassifier(
    criterion='entropy',
    max_features=10,
    max_depth=16,
    min_samples_split=10
)

#set start time
start_time_tree = datetime.datetime.now()

#train our tree
decision_tree.fit(train_X, train_Y)

# Classify, storing the result in a new variable.
y_pred_dtree = decision_tree.predict(test_X)

#get accuracy score from our model
print('Accuracy score for decision tree Model: ' + str(metrics.accuracy_score(test_Y, y_pred_dtree)))

#calculate end time
end_time_tree = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time_tree - start_time_tree))
print()

#get accuracy score of decision tree
tree_score = cross_val_score(decision_tree, df_X, Y, cv=10, scoring='accuracy')
print(tree_score)
print('Average cross validated score from our decision tree model is: ' + str(np.mean(tree_score)))
# Out:
# Accuracy score for decision tree Model: 0.6671860361421035
#
# Duration: 0:00:05.523208
#
# [0.66996067 0.67014854 0.66723447 0.66703407 0.66782315 0.66847445
#  0.67044088 0.6694514  0.66684619 0.66822395]
# Average cross validated score from our decision tree model is: 0.6685637772815237

# %%
#Get AUC and create ROC
# predict probabilities
probs_dtree = decision_tree.predict_proba(test_X)
# keep probabilities for the positive outcome only
probs_dtree = probs_dtree[:, 1]
# calculate AUC
dtree_auc = roc_auc_score(test_Y, probs_dtree)
print('AUC Score: %.3f' % dtree_auc)
# calculate roc curve
fpr_dtree, tpr_dtree, thresholds_dtree = roc_curve(test_Y, probs_dtree)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_dtree, tpr_dtree, marker='.')
# show the plot
plt.show()
print()

# create confusion matrix for random forest and PCA
print("Confusion Matrix: \n", confusion_matrix(test_Y, y_pred_dtree))
print()

# perform classification report of the logistic regression model
class_names = ['Class_0', 'Class_1']
dtree_report = classification_report(test_Y, y_pred_dtree, target_names=class_names)
print(dtree_report)
# Out:
# AUC Score: 0.722
# Confusion Matrix:
#  [[66166 33095]
#  [33335 67005]]
#
#               precision    recall  f1-score   support
#
#      Class_0       0.66      0.67      0.67     99261
#      Class_1       0.67      0.67      0.67    100340
#
#    micro avg       0.67      0.67      0.67    199601
#    macro avg       0.67      0.67      0.67    199601
# weighted avg       0.67      0.67      0.67    199601

# %%
#dropping some columns and creating the dataframe for the independent variables, including 'dist_sqrt' and 'VehicleToDestination_sqrt'
df_X_linear = df_resampled.drop(['RecordedAtTime', 'ArrivalProximityText', 'Unnamed: 17', 'PublishedLineName', 'VehicleRef', 
                 'NextStopPointName', 'ExpectedArrivalTime', 'ScheduledArrivalTime', 'on_time', 'OriginName', 
                 'DestinationName','source', 'destination', 'Vehicle_location2', 'DistanceFromStop', 'Scheduled_datetime', 
                 'Expected_datetime', 'delay', 'delay_second', 'delay_minute', 'delay_days', 'source', 
                 'destination', 'expected_date'], 1)

# %%
#creating initial train_test_split, before PCA
train_X_linear, test_X_linear, train_Y_linear, test_Y_linear = train_test_split(df_X_linear, Y, test_size=.25)
print(test_X_linear.shape)
print(test_Y_linear.shape)

#checking for any NaN values in our data.
#print(np.isnan(train_Y).any())
#print(np.isnan(train_X).any().sum())
#print(np.isnan(test_Y).any())
#print(np.isnan(test_X).any().sum())
# Out:
# (199601, 12)
# (199601,)

# %% [markdown]
# # Logistic Regression

# %%
#initialize and train our logistic regression model with "dist_squared" and "VehicleToDestination_squared" added to 
#create linear relationship 
#with output variable.
LogReg_linear = LogisticRegression(C=1e9)

#set start time
start_time4 = datetime.datetime.now()

#fit and train the model
LogReg_linear.fit(train_X_linear, train_Y_linear)

# Classify, storing the result in a new variable.
y_pred_LogReg_linear = LogReg_linear.predict(test_X_linear)

#get accuracy score from our model
print('Accuracy score for Logistic regression Model: ' + str(metrics.accuracy_score(test_Y_linear, y_pred_LogReg_linear)))

#calculate end time
end_time4 = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time4 - start_time4))
print()

#get average accuracy score using cross validation
LogReg_cvs_linear = cross_val_score(LogReg_linear, df_X_linear, Y, cv=10, scoring='accuracy')
print(LogReg_cvs_linear)

print('Average cross validated score from our log regression model is: ' + str(np.mean(LogReg_cvs_linear)))
# Out:
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy score for Logistic regression Model: 0.611089122799986
#
# Duration: 0:00:10.446666
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [0.61056837 0.61363693 0.61419088 0.61162325 0.60996994 0.61272545
#  0.60971944 0.61172345 0.61262525 0.6134519 ]
# Average cross validated score from our log regression model is: 0.6120234864596557

# %%
#Get AUC and create ROC
# predict probabilities
probs_LogReg_linear = LogReg_linear.predict_proba(test_X_linear)
# keep probabilities for the positive outcome only
probs_LogReg_linear = probs_LogReg_linear[:, 1]
# calculate AUC
LogReg_auc = roc_auc_score(test_Y_linear, probs_LogReg_linear)
print('AUC Score: %.3f' % LogReg_auc)
# calculate roc curve
fpr_LogReg, tpr_LogReg, thresholds_LogReg = roc_curve(test_Y_linear, probs_LogReg_linear)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_LogReg, tpr_LogReg, marker='.')
# show the plot
plt.show()
print()

# create confusion matrix for random forest and PCA
print("Confusion Matrix: \n", confusion_matrix(test_Y_linear, y_pred_LogReg_linear))
print()

# perform classification report of the logistic regression model
class_names = ['Class_0', 'Class_1']
LogReg_linear_report = classification_report(test_Y_linear, y_pred_LogReg_linear, target_names=class_names)
print(LogReg_linear_report)
# Out:
# AUC Score: 0.656
# Confusion Matrix:
#  [[59251 40540]
#  [37087 62723]]
#
#               precision    recall  f1-score   support
#
#      Class_0       0.62      0.59      0.60     99791
#      Class_1       0.61      0.63      0.62     99810
#
#    micro avg       0.61      0.61      0.61    199601
#    macro avg       0.61      0.61      0.61    199601
# weighted avg       0.61      0.61      0.61    199601

# %% [markdown]
# # PCA

# %%
# Normalize the data so that all variables have a mean of 0 and standard deviation
# o

X_scaled = StandardScaler().fit_transform(df_X)
# Out:
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
#Apply PCA

pca = PCA(.95)
df_X_pca = pca.fit_transform(X_scaled)

comp_no = pca.n_components_
comp_var_ratio = pca.explained_variance_ratio_

print(comp_no)
print(comp_var_ratio)
#print(p_components)
# Out:
# 7
# [0.39468092 0.14992537 0.13284612 0.12992316 0.09975476 0.04261922
#  0.02226643]

# %%
#pca data to dataframe
pca_df = pd.DataFrame(data=df_X_pca)
print(pca_df.head())
print(pca_df.shape)
# Out:
#           0         1         2         3         4         5         6
# 0 -1.222510  1.266434 -1.395774 -0.051103 -0.782131  0.786603 -0.393095
# 1  1.859116 -1.727556 -1.056338  0.350363  0.218868 -0.416133  0.247878
# 2 -0.049629  0.475869 -1.577057 -1.046031 -0.030255 -0.619770  0.135265
# 3  2.321088 -1.097677 -1.389632 -0.917027  0.460165  0.337991 -0.740704
# 4  0.985811 -1.026142  1.030579 -0.740647 -1.089314 -0.639703 -0.244096
# (798404, 7)

# %%
#subset dataframe X to include only the first 600,000 rows.
df_X_SmallSet = pca_df.iloc[:200000, :]
print(df_X_SmallSet.shape)

#getting a smaller sample set for output variable Y 
Y_SmallSet = Y[:200000]
print(Y_SmallSet.shape)
# Out:
# (200000, 7)
# (200000,)

# %%
#checking the values in Y
set(Y_SmallSet)
# Out:
# {0, 1}

# %%
#creating a train test split based on PCA and full data set.
train_X_PCA, test_X_PCA, train_Y_PCA, test_Y_PCA = train_test_split(pca_df, Y, test_size=.25)
print(test_X_PCA.shape)
print(test_Y_PCA.shape)
# Out:
# (199601, 7)
# (199601,)

# %%
#creating a second train test split based on PCA and small data set.
train_X_SmallPCA, test_X_SmallPCA, train_Y_SmallPCA, test_Y_SmallPCA = train_test_split(df_X_SmallSet, Y_SmallSet, test_size=.25)
print(test_X_SmallPCA.shape)
print(test_Y_SmallPCA.shape)
# Out:
# (50000, 7)
# (50000,)

# %%
#initialize and train our Logistic regression model using PCA
#with output variable.
LogReg_PCA= LogisticRegression(C=1e9)

#set start time
start_time4 = datetime.datetime.now()

#fit and train the model
LogReg_PCA.fit(train_X_PCA, train_Y_PCA)

# Classify, storing the result in a new variable.
y_pred_LogReg_PCA = LogReg_PCA.predict(test_X_PCA)

#get accuracy score from our model
print('Accuracy score for Logistic regression Model: ' + str(metrics.accuracy_score(test_Y_PCA, y_pred_LogReg_PCA)))

#calculate end time
end_time4 = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time4 - start_time4))
print()

#get average accuracy score using cross validation
LogReg_cvs_PCA = cross_val_score(LogReg_linear, pca_df, Y, cv=10, scoring='accuracy')
print(LogReg_cvs_PCA)

print('Average cross validated score from our log regression model is: ' + str(np.mean(LogReg_cvs_PCA)))
# Out:
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Accuracy score for Logistic regression Model: 0.6126572512161763
#
# Duration: 0:00:01.133933
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\sajee\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# [0.60989204 0.61376218 0.61437876 0.61059619 0.60807866 0.61251253
#  0.60839178 0.61032064 0.61168587 0.61351453]
# Average cross validated score from our log regression model is: 0.6113133174994562

# %% [markdown]
# # Random Forest with Full Features

# %%
# perform grid search to find the optimal parameters for our random forest model, with full features
rforest_fulldata = ensemble.RandomForestClassifier()
forest_param_grid = {'n_estimators':[60], 'max_depth':[6,8,10], 'min_samples_split':[8,10], 
                     'max_features':[2,4,6,8], 'criterion':['entropy', 'gini']}
rforest_grid_FullData = GridSearchCV(rforest_fulldata, forest_param_grid, cv=10, verbose=3)
rforest_grid_FullData.fit(train_X_FullDataSmall, train_Y_FullDataSmall)
# Out:
# Fitting 10 folds for each of 48 candidates, totalling 480 fits
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6496311438983201, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.7s remaining:    0.0s
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6404764020975914, total=   3.2s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    7.3s remaining:    0.0s
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6433205937250023, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6484756910496845, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6483555555555556, total=   3.4s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6366222222222222, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6464574628855898, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6445017334874211, total=   3.5s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6400568939461285, total=   3.4s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=60, score=0.6414792425993422, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6474980001777619, total=   3.2s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6408319260510177, total=   3.4s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6410096880277308, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6432317127366456, total=   3.4s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6395555555555555, total=   3.2s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6355555555555555, total=   3.3s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6459240821406347, total=   3.4s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6446795270690728, total=   3.5s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6389012356653925, total=   3.5s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=60, score=0.6417459329718197, total=   3.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6434983557017154, total=   6.3s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6392320682605991, total=   6.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6410985690160874, total=   6.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6432317127366456, total=   6.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6417777777777778, total=   6.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6381333333333333, total=   6.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6453018046048538, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6441461463241177, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6400568939461285, total=   6.3s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=60, score=0.6398791003644768, total=   6.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6451870944804906, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6375433294818238, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6418984979112968, total=   5.9s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.645098213492134, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6448888888888888, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6382222222222222, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6433460752066851, total=   6.0s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6455684949773313, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.6367677126855721, total=   6.0s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=60, score=0.63916792603787, total=   6.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.64207625988801, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.639676473202382, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6394987112256688, total=   8.7s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.645542618433917, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6428444444444444, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6434666666666666, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6425460040892523, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.642723797670904, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6367677126855721, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=60, score=0.6354342608231843, total=   9.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6438538796551417, total=   8.7s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6392320682605991, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.64207625988801, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6419873788996534, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6428444444444444, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6415111111111111, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6445906302782469, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6437905591608143, total=   8.8s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6374788870121788, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=60, score=0.6364121255222687, total=   8.9s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6428761887832193, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6397653541907387, total=  11.6s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6439427606434983, total=  11.6s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.643142831748289, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6441777777777777, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6417777777777778, total=  11.6s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6437905591608143, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6423682105076006, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6363232287314428, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=8, n_estimators=60, score=0.6358787447773135, total=  11.9s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6412763309928007, total=  12.1s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.640565283085948, total=  11.9s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6422540218647231, total=  11.6s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6408319260510177, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6422222222222222, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6426666666666667, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.643968352742466, total=  11.7s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6408569650635612, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6328562538892346, total=  11.8s
# [CV] criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=6, max_features=8, min_samples_split=10, n_estimators=60, score=0.6389012356653925, total=  11.6s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6610079104079637, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6466091902941961, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6497200248866768, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6542529552928629, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6519111111111111, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6493333333333333, total=   4.4s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6515245799626633, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6501022313094498, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6469908436305449, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=8, n_estimators=60, score=0.6474353275846741, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6551417651764287, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.645098213492134, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6504310727935295, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6521198115723047, total=   4.2s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6532444444444444, total=   4.1s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6478222222222222, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6535692061516579, total=   4.4s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6519690639167927, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6459240821406347, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=2, min_samples_split=10, n_estimators=60, score=0.6491243666103653, total=   4.3s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6551417651764287, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6469647142476225, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6506977157585992, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6578081948271265, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6537777777777778, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6516444444444445, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6530358254067028, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6513467863810116, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6501022313094498, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=8, n_estimators=60, score=0.6478798115388035, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6555861701182117, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6467869522709092, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.652475335525731, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6553195271531419, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6522666666666667, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6546666666666666, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6528580318250511, total=   7.7s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.651791270335141, total=   7.9s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.646368566094764, total=   8.0s
# [CV] criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=4, min_samples_split=10, n_estimators=60, score=0.6477909147479776, total=   7.8s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6567416229668473, total=  11.5s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6480312861079015, total=  11.7s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6538974313394365, total=  11.6s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6535419073860101, total=  11.8s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6528, total=  11.9s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6506666666666666, total=  11.6s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6503689216819273, total=  11.7s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6524135478709219, total=  11.5s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6456573917681572, total=  11.6s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=8, n_estimators=60, score=0.6498355409369722, total=  11.7s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6546084792462892, total=  11.5s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6495422629099635, total=  11.8s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6504310727935295, total=  11.7s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6526530975024443, total=  11.6s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6560888888888889, total=  11.7s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6512888888888889, total=  12.0s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6525913414525736, total=  11.9s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6524135478709219, total=  11.9s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6440572495332918, total=  12.0s
# [CV] criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=6, min_samples_split=10, n_estimators=60, score=0.6498355409369722, total=  12.0s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6546084792462892, total=  15.9s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6461647853524132, total=  15.5s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6506088347702427, total=  15.8s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6522975735490179, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6535111111111112, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6497777777777778, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6490354698195395, total=  15.3s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.651702373544315, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6449462174415503, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=8, n_estimators=60, score=0.6479687083296293, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6541640743045063, total=  15.3s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6466091902941961, total=  15.5s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6501644298284597, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6505199537818861, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6552, total=  15.4s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6503111111111111, total=  15.8s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6503689216819273, total=  15.7s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6512578895901858, total=  15.6s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.643968352742466, total=  15.6s
# [CV] criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=8, max_features=8, min_samples_split=10, n_estimators=60, score=0.6500133345186239, total=  15.4s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6665185316860723, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6550528841880722, total=   5.3s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6560305750599946, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6631410541285219, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6584, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6562666666666667, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6626366788158947, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6573028713663437, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6552582451773491, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=8, n_estimators=60, score=0.6559694195039559, total=   5.3s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6626077681983824, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.654430717269576, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6549640031997156, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6640298640120879, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6584888888888889, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6569777777777778, total=   5.3s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6613921237443329, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6586363232287314, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6524135478709219, total=   5.1s
# [CV] criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6563250066672593, total=   5.2s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6631410541285219, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6552306461647853, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6576304328504133, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.662252244244956, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6618666666666667, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6592888888888889, total=  10.1s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6641479242599342, total=   9.9s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6587252200195572, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6535692061516579, total=   9.6s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6541914836874388, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.663763221047018, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6552306461647853, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6590525286641188, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.661185672384677, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6610666666666667, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6583111111111111, total=   9.4s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6614810205351587, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6577473553204729, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6526802382433994, total=   9.8s
# [CV] criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6572139745755178, total=   9.7s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6641187450004444, total=  14.3s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6569193849435606, total=  14.3s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6581637187805528, total=  14.7s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6584303617456226, total=  14.6s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6638222222222222, total=  14.8s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6625777777777778, total=  14.5s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6585474264379055, total=  14.6s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6578362521112988, total=  14.4s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6549915548048716, total=  14.7s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6565916970397369, total=  14.7s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6642965069771576, total=  14.7s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=entropy, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6575415518620568, total=  14.9s
# [CV] criterion=entropy, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# ...
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6522086925606613, total=   4.1s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6590525286641188, total=   4.1s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6644742689538707, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6631111111111111, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6576888888888889, total=   4.2s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6627255756067206, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6581918392746022, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6556138323406525, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=2, min_samples_split=10, n_estimators=60, score=0.6550804515956974, total=   4.0s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6641187450004444, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6592302906408319, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6577193138387699, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.663763221047018, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6605333333333333, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6594666666666666, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.661303226953507, total=   7.5s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6596141879278158, total=   7.3s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6561472130856076, total=   7.3s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=8, n_estimators=60, score=0.6590808071828607, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6670518176162119, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6577193138387699, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6583414807572661, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6619856012798863, total=   7.5s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6625777777777778, total=   7.3s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6599111111111111, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6626366788158947, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6587252200195572, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6531247221975287, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=4, min_samples_split=10, n_estimators=60, score=0.6589919103920349, total=   7.4s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6629632921518087, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6562083370367079, total=  10.6s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6580748377921962, total=  10.8s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6638521020353746, total=  10.9s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6647111111111111, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6615111111111112, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6589919103920349, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6563250066672593, total=  10.9s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6566805938305628, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=8, n_estimators=60, score=0.6584585296470797, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6689183183717002, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6557639320949249, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6605635054661808, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6641187450004444, total=  10.9s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6629333333333334, total=  10.8s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6618666666666667, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6626366788158947, total=  10.8s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.658903013601209, total=  10.6s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6540136901057871, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=6, min_samples_split=10, n_estimators=60, score=0.6611254333718553, total=  10.7s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6651853168607235, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6560305750599946, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.658785885699049, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.664207625988801, total=  14.0s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6648, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6599111111111111, total=  14.2s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6600586718819451, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.658903013601209, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6536581029424838, total=  14.2s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=8, n_estimators=60, score=0.6592586007645124, total=  14.2s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6636743400586614, total=  14.0s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6546084792462892, total=  14.0s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6610079104079637, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.662696649186739, total=  14.2s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6648, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6597333333333333, total=  14.1s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6607698462085518, total=  14.2s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6598808783002934, total=  14.0s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6573917681571695, total=  14.0s
# [CV] criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60
# [CV]  criterion=gini, max_depth=10, max_features=8, min_samples_split=10, n_estimators=60, score=0.6590808071828607, total=  14.2s
# [Parallel(n_jobs=1)]: Done 480 out of 480 | elapsed: 74.2min finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-321-1b2f5e12081d> in <module>
#       5 rforest_grid_FullData = GridSearchCV(rforest_fulldata, forest_param_grid, cv=10, verbose=3)
#       6 rforest_grid_FullData.fit(train_X_FullDataSmall, train_Y_FullDataSmall)
# ----> 7 print('Best parameters for random forest with full features:', rforest_grid_FullDataSmall.best_params_)
#       8 print('Best score for random forest with full features:', rforest_grid_FullDataSmall.best_score_)
#
# NameError: name 'rforest_grid_FullDataSmall' is not defined

# %%
print('Best parameters for random forest with full features:', rforest_grid_FullData.best_params_)
print('Best score for random forest with full features:', rforest_grid_FullData.best_score_)
# Out:
# Best parameters for random forest with full features: {'criterion': 'gini', 'max_depth': 10, 'max_features': 6, 'min_samples_split': 10, 'n_estimators': 60}
# Best score for random forest with full features: 0.6610844444444445

# %%
#initialize and train random forest model with full features
rand_forest = ensemble.RandomForestClassifier(n_estimators=100, criterion='gini', max_depth=16, max_features=6,
                                              min_samples_split=10)

#set start time
start_time_rforest = datetime.datetime.now()

rand_forest.fit(train_X, train_Y)

# Classify, storing the result in a new variable.
y_pred_rforest = rand_forest.predict(test_X)

#get accuracy score from our model
print('Accuracy score for Random Forest Model: ' + str(metrics.accuracy_score(test_Y, y_pred_rforest)))

#calculate end time
end_time_rforest = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time_rforest - start_time_rforest))
print()
# Out:
# Accuracy score for Random Forest Model: 0.6837590994033096
#
# Duration: 0:03:30.592220

# %%
#using the feature_importances_ attribute to check for most important features.
rand_forest.feature_importances_
# Out:
# array([0.00235936, 0.06362668, 0.0483804 , 0.03698613, 0.03328519,
#        0.11797341, 0.11776711, 0.23592617, 0.10841279, 0.23528275])

# %%
#putting the information from random forest feature_importance_ into a dataframe to graph the data
df_importances = pd.DataFrame({'feature':df_X.columns,'importance':np.round(rand_forest.feature_importances_,3)})
df_importances = df_importances.sort_values('importance',ascending=False).set_index('feature')

# %%
df_importances.head(10)
# Out:
#                            importance
# feature
# Scheduled_HourOfDay             0.236
# VehicleToDestination            0.235
# VehicleLocation.Latitude        0.118
# VehicleLocation.Longitude       0.118
# dist                            0.108
# OriginLat                       0.064
# OriginLong                      0.048
# DestinationLat                  0.037
# DestinationLong                 0.033
# DirectionRef                    0.002

# %%
#graphing feature importance
df_importances.plot.bar()

# %%
#get average accuracy score of our random forest through cross validation
rforest_cvs = cross_val_score(rand_forest, df_X, Y, cv=10, scoring='accuracy')
print(rforest_cvs)
print('Average cross validated score from our Random Forest Model is: ' + str(np.mean(rforest_cvs)))
# Out:
# [0.68673129 0.68279853 0.68558367 0.68411824 0.68461924 0.68345441
#  0.68202655 0.6824524  0.68152555 0.68334168]
# Average cross validated score from our Random Forest Model is: 0.6836651564884234

# %%
#Get AUC and create ROC for Random Forest
# predict probabilities
probs_rforest = rand_forest.predict_proba(test_X)
# keep probabilities for the positive outcome only
probs_rforest = probs_rforest[:, 1]
# calculate AUC
rforest_auc = roc_auc_score(test_Y, probs_rforest)
print('AUC Score: %.3f' % rforest_auc)
# calculate roc curve
fpr_rforest, tpr_rforest, thresholds_rforest = roc_curve(test_Y, probs_rforest)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_rforest, tpr_rforest, marker='.')
# show the plot
plt.show()
print()

# create confusion matrix for random forest and PCA
print("Confusion Matrix: \n", confusion_matrix(test_Y, y_pred_rforest))
print()

# perform classification report of the logistic regression model
class_names = ['Class_0', 'Class_1']
rforest_report = classification_report(test_Y, y_pred_rforest, target_names=class_names)
print(rforest_report)
# Out:
# AUC Score: 0.749
# Confusion Matrix:
#  [[68930 30825]
#  [32297 67549]]
#
#               precision    recall  f1-score   support
#
#      Class_0       0.68      0.69      0.69     99755
#      Class_1       0.69      0.68      0.68     99846
#
#    micro avg       0.68      0.68      0.68    199601
#    macro avg       0.68      0.68      0.68    199601
# weighted avg       0.68      0.68      0.68    199601

# %% [markdown]
# ## Random Forest Using PCA Data

# %%
# perform grid search to find the optimal parameters for our random forest model, after applying PCA
rforest = ensemble.RandomForestClassifier(random_state=20)
forest_param_grid = {'n_estimators':[100], 'max_depth':[4,6], 'min_samples_split':[6,8,10], 
                     'max_features':[2,4,6], 'criterion':['entropy', 'gini']}
rforest_grid = GridSearchCV(rforest, forest_param_grid, cv=10, verbose=3)
rforest_grid.fit(train_X_SmallPCA, train_Y_SmallPCA)
print('Best parameters for decision tree:', rforest_grid.best_params_)
# Out:
# Fitting 10 folds for each of 36 candidates, totalling 360 fits
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6311579228051464, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.5s remaining:    0.0s
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.625491633891074, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   27.1s remaining:    0.0s
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6290247316845544, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6285333333333334, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.633, total=  13.0s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6265333333333334, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6288, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6265084338955931, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6331088739249283, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.628841922794853, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6310912605826279, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.626824878341444, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6290247316845544, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6285333333333334, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.633, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6265333333333334, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6284, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.626975131675445, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6331088739249283, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.628841922794853, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6310912605826279, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.626824878341444, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6290247316845544, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6281333333333333, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6328, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6261333333333333, total=  12.7s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6284, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6268417894526301, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6335755717047803, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6282418827921862, total=  12.6s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6268915405639625, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6247583494433704, total=  23.6s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.625491633891074, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6259333333333333, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6314, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6216666666666667, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6193333333333333, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6221748116541103, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6265084338955931, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6199746649776652, total=  23.5s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6268915405639625, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6245583627758149, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.625624958336111, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6259333333333333, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6314, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6216666666666667, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6193333333333333, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6221081405427028, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6264417627841856, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=8, n_estimators=100, score=0.6199746649776652, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.626291580561296, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6246250249983334, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.625891607226185, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6259333333333333, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6324666666666666, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6216666666666667, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6193333333333333, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6221081405427028, total=  23.2s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6264417627841856, total=  23.4s
# [CV] criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=4, min_samples_split=10, n_estimators=100, score=0.6200413360890726, total=  23.3s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6252916472235185, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6220918605426304, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6231584561029264, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6248, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6325333333333333, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6179333333333333, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.618, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6201746783118874, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6236415761050736, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=6, n_estimators=100, score=0.6194412960864057, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6252916472235185, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6220918605426304, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6231584561029264, total=  34.2s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6248, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6325333333333333, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6179333333333333, total=  33.9s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.618, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6201746783118874, total=  34.2s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6236415761050736, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=8, n_estimators=100, score=0.6194412960864057, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6252916472235185, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6220918605426304, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6231584561029264, total=  33.9s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6248, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6325333333333333, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6179333333333333, total=  33.9s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.618, total=  34.1s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6201746783118874, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6236415761050736, total=  34.0s
# [CV] criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=4, max_features=6, min_samples_split=10, n_estimators=100, score=0.6194412960864057, total=  34.1s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6426904873008467, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6406239584027732, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6390907272848477, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6384666666666666, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6428666666666667, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6375333333333333, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6428666666666667, total=  17.7s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6364424294952997, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6423761584105607, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=6, n_estimators=100, score=0.6387759183945596, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6430237984134392, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6405572961802547, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6388907406172922, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6374, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6438666666666667, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6369333333333334, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6428666666666667, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6364424294952997, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6426428428561904, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6383092206147076, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6434237717485501, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6397573495100327, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6396906872875142, total=  18.0s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6384, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6424666666666666, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.637, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6449333333333334, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6367757850523368, total=  17.9s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.643042869524635, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6385759050603373, total=  17.8s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6340243983734418, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6324911672555164, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6330911272581828, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6372, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6414, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.633, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6304, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6331755450363358, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6303753583572238, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6287752516834456, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6348910072661823, total=  33.2s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6323578428104794, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6326244917005533, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6372, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6413333333333333, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6326666666666667, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6299333333333333, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6331755450363358, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.631175411694113, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6295086339089273, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6340910605959603, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6320911939204054, total=  33.6s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6332911139257383, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6376666666666667, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6412666666666667, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.633, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6301333333333333, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6327755183678911, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6323088205880392, total=  33.5s
# [CV] criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6297086472431496, total=  33.4s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6344243717085528, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6328244783681088, total=  49.5s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6339577361509233, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6360666666666667, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6386666666666667, total=  48.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6313333333333333, total=  48.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6317333333333334, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6330422028135209, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6307753850256683, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6289085939062604, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6342910472635158, total=  48.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6330911272581828, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6336244250383308, total=  48.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6362, total=  50.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6388, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6309333333333333, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6318666666666667, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6341756117074472, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6313087539169278, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6294419627975198, total=  49.2s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6340910605959603, total=  49.2s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6323578428104794, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6336244250383308, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6360666666666667, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6392666666666666, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6308666666666667, total=  49.1s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.632, total=  48.9s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6337089139275952, total=  49.0s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6314420961397427, total=  49.3s
# [CV] criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=entropy, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6286419094606307, total=  49.2s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6323578428104794, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.627491500566629, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6288247450169989, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6282666666666666, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6342666666666666, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6263333333333333, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6287333333333334, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6266417761184079, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6315754383625575, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=6, n_estimators=100, score=0.6280418694579639, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6323578428104794, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.627491500566629, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6288247450169989, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6282666666666666, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6342666666666666, total=   9.1s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6263333333333333, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6287333333333334, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6266417761184079, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6315754383625575, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=8, n_estimators=100, score=0.6280418694579639, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6323578428104794, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.627491500566629, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6288247450169989, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6282666666666666, total=   9.3s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6342666666666666, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6263333333333333, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6287333333333334, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6266417761184079, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6315754383625575, total=   8.9s
# [CV] criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=2, min_samples_split=10, n_estimators=100, score=0.6280418694579639, total=   9.0s
# [CV] criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6272915138990734, total=  16.0s
# [CV] criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.6248250116658889, total=  16.0s
# [CV] criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100, score=0.625758282781148, total=  16.0s
# [CV] criterion=gini, max_depth=4, max_features=4, min_samples_split=6, n_estimators=100
# ...
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6435762384158944, total=  12.4s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=8, n_estimators=100, score=0.6389759317287819, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6434904339710686, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6387574161722552, total=  12.4s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6411572561829212, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6402666666666667, total=  12.4s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6431333333333333, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6392, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6416666666666667, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6376425095006334, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.6434428961930795, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=2, min_samples_split=10, n_estimators=100, score=0.639442629508634, total=  12.3s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6362909139390708, total=  22.5s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6315578961402574, total=  22.5s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6336910872608493, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6376, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6416666666666667, total=  22.3s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6338666666666667, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6314666666666666, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6319087939195946, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6345089672644842, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=6, n_estimators=100, score=0.6295086339089273, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6358242783814413, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6323578428104794, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6345576961535898, total=  22.5s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6383333333333333, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6418, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6338666666666667, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6306666666666667, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6318421228081872, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6345089672644842, total=  22.3s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=8, n_estimators=100, score=0.6293086205747049, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6354243050463303, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6319578694753684, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6344910339310713, total=  22.6s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6379333333333334, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6416, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6339333333333333, total=  22.3s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6305333333333333, total=  22.5s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6319087939195946, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6341756117074472, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=4, min_samples_split=10, n_estimators=100, score=0.6298419894659644, total=  22.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6339577361509233, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6329578028131458, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6345576961535898, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6371333333333333, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6386, total=  32.3s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6313333333333333, total=  32.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6311333333333333, total=  32.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6327088472564838, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6318421228081872, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=6, n_estimators=100, score=0.6275085005667045, total=  32.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6339577361509233, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6327578161455903, total=  32.3s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6345576961535898, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6368, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6385333333333333, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6312666666666666, total=  32.2s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6317333333333334, total=  32.3s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6332422161477432, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.6309753983598907, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=8, n_estimators=100, score=0.627908527235149, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6342243850409973, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6328244783681088, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6346243583761083, total=  32.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6366, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6383333333333333, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6316666666666667, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6318, total=  32.6s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6335089005933728, total=  32.4s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6316421094739649, total=  32.5s
# [CV] criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100
# [CV]  criterion=gini, max_depth=6, max_features=6, min_samples_split=10, n_estimators=100, score=0.6281085405693713, total=  32.6s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 149.0min finished
# Best parameters for decision tree: {'criterion': 'gini', 'max_depth': 6, 'max_features': 2, 'min_samples_split': 10, 'n_estimators': 100}

# %%
print('Best score for Random Forest:', rforest_grid.best_score_)
# Out:
# Best score for Random Forest: 0.64082

# %%
#initialize and train our random forest model with PCA
rand_forest_pca = ensemble.RandomForestClassifier(n_estimators=200, criterion='gini', max_depth=16, max_features=4,
                                              min_samples_split=10)

#set start time
start_time_rforest = datetime.datetime.now()

rand_forest_pca.fit(train_X_PCA, train_Y_PCA)

# Classify, storing the result in a new variable.
y_pred_rforest_pca = rand_forest_pca.predict(test_X_PCA)

#get accuracy score from our model
print('Accuracy score for Random Forest Model: ' + str(metrics.accuracy_score(test_Y_PCA, y_pred_rforest_pca)))

#calculate end time
end_time_rforest = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time_rforest - start_time_rforest))
print()

#get average accuracy score of our random forest through cross validation
rforest_pca_cvs = cross_val_score(rand_forest_pca, pca_df, Y, cv=5, scoring='accuracy')
print(rforest_pca_cvs)
print('Average cross validated score from our Random Forest Model is: ' + str(np.mean(rforest_pca_cvs)))
# Out:
# Accuracy score for Random Forest Model: 0.6784034148125511
#
# Duration: 0:24:12.723109
#
# [0.68258561 0.67904111 0.67917084 0.67871994 0.68151303 0.68191383
#  0.68232715 0.68041082 0.67954659 0.68280311]
# Average cross validated score from our Random Forest Model is: 0.680803202337894

# %%
#Get AUC and create ROC from random forest built with pca
# predict probabilities
probs_rforest_pca = rand_forest_pca.predict_proba(test_X_PCA)
# keep probabilities for the positive outcome only
probs_rforest_pca = probs_rforest_pca[:, 1]
# calculate AUC
rforest_auc = roc_auc_score(test_Y_PCA, probs_rforest_pca)
print('AUC Score: %.3f' % rforest_auc)
# calculate roc curve
fpr_rforest_pca, tpr_rforest_pca, thresholds_rforest_pca = roc_curve(test_Y_PCA, probs_rforest_pca)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_rforest_pca, tpr_rforest_pca, marker='.')
# show the plot
plt.show()
print()


# create confusion matrix for random forest and PCA
print("Confusion Matrix: \n", confusion_matrix(test_Y_PCA, y_pred_rforest_pca))
print()

# perform classification report of the logistic regression model
class_names = ['Class_0', 'Class_1']
rforest_report_pca = classification_report(test_Y_PCA, y_pred_rforest_pca, target_names=class_names)
print(rforest_report_pca)
# Out:
# AUC Score: 0.774
# Confusion Matrix:
#  [[50330 49610]
#  [50533 49128]]
#
#               precision    recall  f1-score   support
#
#      Class_0       0.50      0.50      0.50     99940
#      Class_1       0.50      0.49      0.50     99661
#
#    micro avg       0.50      0.50      0.50    199601
#    macro avg       0.50      0.50      0.50    199601
# weighted avg       0.50      0.50      0.50    199601

# %% [markdown]
# # KNN

# %%
# perform grid search to find the optimal parameters for our KNN model using full data.
KNN_model = KNeighborsClassifier()
KNN_params = {'n_neighbors':[5,10,15], 'weights':['uniform', 'distance']}
KNN_grid = GridSearchCV(KNN_model, KNN_params, cv=10, verbose=3)
KNN_grid.fit(train_X_FullDataSmall, train_Y_FullDataSmall)
print('Best parameters for data:', KNN_grid.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_neighbors=5, weights=uniform, score=0.613189938672118, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV]  n_neighbors=5, weights=uniform, score=0.6054572926850946, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.1s remaining:    0.0s
# [CV]  n_neighbors=5, weights=uniform, score=0.6125677717536219, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6127111111111111, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6122666666666666, total=   0.3s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6077333333333333, total=   0.3s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6134222222222222, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6209440839185706, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.611165436927727, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6114321273002045, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6057239356501645, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6019909341391876, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6068793884988001, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6068444444444444, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] ..... n_neighbors=5, weights=distance, score=0.608, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] .... n_neighbors=5, weights=distance, score=0.6016, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6076444444444444, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.617654902658014, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6103653658102942, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6138323406525025, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6192338458803662, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6127455337303351, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.61470091547418, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.612, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6143111111111111, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6158222222222223, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] .... n_neighbors=10, weights=uniform, score=0.6104, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6157880700506712, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6148102053515868, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6175660058671882, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6168340591947382, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6079459603590792, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6107901519864901, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6132444444444445, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6171555555555556, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6102222222222222, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6132444444444445, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6222775357809583, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6151657925148902, total=   0.2s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6160547604231488, total=   0.2s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6289218736112345, total=   0.2s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6215447515776376, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6170118211714515, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6230222222222223, total=   0.2s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6232888888888889, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6218666666666667, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] .... n_neighbors=15, weights=uniform, score=0.6152, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6285892079295937, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6208551871277447, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6238776780158236, total=   0.2s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6221669184961337, total=   0.2s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6139009865789707, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6142565105323972, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6164444444444445, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6213333333333333, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6157333333333334, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6165333333333334, total=   0.2s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6285892079295937, total=   0.2s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6217441550360032, total=   0.3s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.621833051826829, total=   0.3s
# Best parameters for data: {'n_neighbors': 15, 'weights': 'uniform'}
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  2.1min finished

# %%
#initialize and train our model using full features
KNN = KNeighborsClassifier(n_neighbors=15, weights='uniform')

#set start time
starttime_knn = datetime.datetime.now()

#fit and train the model
KNN.fit(train_X,train_Y)

#Make predictions using test_X, and store results in new variable
y_pred_KNN = KNN.predict(test_X)

print('Accuracy score for KNN Model: ' + str(metrics.accuracy_score(test_Y, y_pred_KNN)))

#calculate end time
endtime_knn = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(endtime_knn - starttime_knn))
print()


KNN_cvs = cross_val_score(KNN, df_X, Y, cv=5, scoring='accuracy')
print(KNN_cvs)
print('Average cross validated score from our KNN model is: ' + str(np.mean(KNN_cvs)))
# Out:
# Accuracy score for KNN Model: 0.6446610988922902
#
# Duration: 0:00:11.443412
#
# [0.64595884 0.64572713 0.64475827 0.64651177 0.64449524]
# Average cross validated score from our KNN model is: 0.6454902512876356

# %%
#Get AUC and create ROC
# predict probabilities
probs_KNN = KNN.predict_proba(test_X)
# keep probabilities for the positive outcome only
probs_KNN = probs_KNN[:, 1]
# calculate AUC
KNN_auc = roc_auc_score(test_Y, probs_KNN)
print('AUC Score: %.3f' % KNN_auc)
# calculate roc curve
fpr_KNN, tpr_KNN, thresholds_KNN = roc_curve(test_Y, probs_KNN)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_KNN, tpr_KNN, marker='.')
# show the plot
plt.show()

# perform classification report of the KNN model
class_names = ['Class_0', 'Class_1']
KNN_report = classification_report(test_Y, y_pred_KNN, target_names=class_names)
print(KNN_report)

# confusion Matrix
print("Confusion Matrix: \n", confusion_matrix(test_Y, y_pred_KNN))
# Out:
# AUC Score: 0.700
#               precision    recall  f1-score   support
#
#      Class_0       0.64      0.67      0.65     99261
#      Class_1       0.65      0.62      0.64    100340
#
#    micro avg       0.64      0.64      0.64    199601
#    macro avg       0.65      0.64      0.64    199601
# weighted avg       0.65      0.64      0.64    199601
#
# Confusion Matrix:
#  [[66095 33166]
#  [37760 62580]]

# %% [markdown]
# ## KNN with PCA

# %%
# perform grid search to find the optimal parameters for our KNN model using full data.
KNN_model_pca = KNeighborsClassifier()
KNN_params = {'n_neighbors':[5,10,15], 'weights':['uniform', 'distance']}
KNN_grid_pca = GridSearchCV(KNN_model, KNN_params, cv=10, verbose=3)
KNN_grid_pca.fit(train_X_SmallPCA, train_Y_SmallPCA)
print('Best parameters for data:', KNN_grid_pca.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_neighbors=5, weights=uniform, score=0.6358909406039598, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV] ..... n_neighbors=5, weights=uniform, score=0.6302, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.8s remaining:    0.0s
# [CV] ..... n_neighbors=5, weights=uniform, score=0.6346, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6334666666666666, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ..... n_neighbors=5, weights=uniform, score=0.6388, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6385333333333333, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6384666666666666, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6362666666666666, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV] ..... n_neighbors=5, weights=uniform, score=0.6458, total=   0.2s
# [CV] n_neighbors=5, weights=uniform ..................................
# [CV]  n_neighbors=5, weights=uniform, score=0.6356423761584106, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6222918472101859, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] .... n_neighbors=5, weights=distance, score=0.6194, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] .... n_neighbors=5, weights=distance, score=0.6196, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6194666666666667, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6203333333333333, total=   0.3s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] .... n_neighbors=5, weights=distance, score=0.6252, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6246666666666667, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV] .... n_neighbors=5, weights=distance, score=0.6284, total=   0.2s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6256666666666667, total=   0.3s
# [CV] n_neighbors=5, weights=distance .................................
# [CV]  n_neighbors=5, weights=distance, score=0.6195079671978132, total=   0.2s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6464902339844011, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6447333333333334, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] ..... n_neighbors=10, weights=uniform, score=0.645, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] .... n_neighbors=10, weights=uniform, score=0.6424, total=   0.4s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6465333333333333, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6500666666666667, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV] .... n_neighbors=10, weights=uniform, score=0.6514, total=   0.4s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6499333333333334, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6520666666666667, total=   0.3s
# [CV] n_neighbors=10, weights=uniform .................................
# [CV]  n_neighbors=10, weights=uniform, score=0.6479765317687846, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6326244917005533, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] .... n_neighbors=10, weights=distance, score=0.631, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6322666666666666, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6284666666666666, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6348666666666667, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6374666666666666, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV] ... n_neighbors=10, weights=distance, score=0.6336, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6368666666666667, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6363333333333333, total=   0.3s
# [CV] n_neighbors=10, weights=distance ................................
# [CV]  n_neighbors=10, weights=distance, score=0.6266417761184079, total=   0.3s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6590893940403973, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6533333333333333, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] .... n_neighbors=15, weights=uniform, score=0.6554, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] .... n_neighbors=15, weights=uniform, score=0.6508, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6578666666666667, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] .... n_neighbors=15, weights=uniform, score=0.6566, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6542666666666667, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV] .... n_neighbors=15, weights=uniform, score=0.6538, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6533333333333333, total=   0.4s
# [CV] n_neighbors=15, weights=uniform .................................
# [CV]  n_neighbors=15, weights=uniform, score=0.6559103940262684, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6363575761615893, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6369333333333334, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6364666666666666, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6350666666666667, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] .... n_neighbors=15, weights=distance, score=0.639, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6410666666666667, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6386666666666667, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV] ... n_neighbors=15, weights=distance, score=0.6432, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6401333333333333, total=   0.4s
# [CV] n_neighbors=15, weights=distance ................................
# [CV]  n_neighbors=15, weights=distance, score=0.6321754783652244, total=   0.4s
# Best parameters for data: {'n_neighbors': 15, 'weights': 'uniform'}
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:  3.0min finished

# %%
#initialize and train our model using the training set
KNN_pca = KNeighborsClassifier(n_neighbors=15, weights='uniform')

#set start time
starttime_knn = datetime.datetime.now()

#fit and train the model
KNN_pca.fit(train_X_PCA,train_Y_PCA)

#Make predictions using test_X, and store results in new variable
y_pred_KNN_pca = KNN_pca.predict(test_X_PCA)

print('Accuracy score for KNN Model: ' + str(metrics.accuracy_score(test_Y_PCA, y_pred_KNN_pca)))

#calculate end time
endtime_knn = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(endtime_knn - starttime_knn))
print()


KNN_cvs_pca = cross_val_score(KNN_pca, pca_df, Y, cv=5, scoring='accuracy')
print(KNN_cvs_pca)
print('Average cross validated score from our KNN model is: ' + str(np.mean(KNN_cvs_pca)))
# Out:
# Accuracy score for KNN Model: 0.6674966558283776
#
# Duration: 0:00:05.926132
#
# [0.66665623 0.66637442 0.66568763 0.66816759 0.66534319]
# Average cross validated score from our KNN model is: 0.6664458090414618

# %%
#Get AUC and create ROC
# predict probabilities
probs_KNN_pca = KNN_pca.predict_proba(test_X_PCA)
# keep probabilities for the positive outcome only
probs_KNN_pca = probs_KNN_pca[:, 1]
# calculate AUC
KNN_pca_auc = roc_auc_score(test_Y_PCA, probs_KNN_pca)
print('AUC Score: %.3f' % KNN_pca_auc)
# calculate roc curve
fpr_KNN_pca, tpr_KNN_pca, thresholds_KNN_pca = roc_curve(test_Y_PCA, probs_KNN_pca)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_KNN_pca, tpr_KNN_pca, marker='.')
# show the plot
plt.show()

# perform classification report of the KNN model
class_names = ['Class_0', 'Class_1']
KNN_report_pca = classification_report(test_Y_PCA, y_pred_KNN_pca, target_names=class_names)
print(KNN_report_pca)

# confusion Matrix
print("Confusion Matrix: \n", confusion_matrix(test_Y_PCA, y_pred_KNN_pca))
# Out:
# AUC Score: 0.725
#               precision    recall  f1-score   support
#
#      Class_0       0.67      0.68      0.67    100167
#      Class_1       0.67      0.66      0.66     99434
#
#    micro avg       0.67      0.67      0.67    199601
#    macro avg       0.67      0.67      0.67    199601
# weighted avg       0.67      0.67      0.67    199601
#
# Confusion Matrix:
#  [[67682 32485]
#  [33883 65551]]

# %%
# perform grid search to find the optimal parameters for our KNN model using full data.
KNN_model = KNeighborsClassifier()
KNN_params = {'n_neighbors':[5,10,15], 'weights':['uniform', 'distance']}
KNN_grid = GridSearchCV(KNN_model, KNN_params, cv=5)
KNN_grid.fit(train_X, train_Y)
print('Best parameters for data:', KNN_grid.best_params_)

# %% [markdown]
# # Gradient Boosting

# %%
#Run gridsearchcv to find the best parameters for gradient boosting using PCA
gboost_param_grid = {'n_estimators':[200], 'max_depth':[8,10,12], 'min_samples_leaf': [5, 8], 
                     'learning_rate': [.01, .02], 'subsample': [.7, .8]}
gb_model = ensemble.GradientBoostingClassifier(random_state=67)

gb_grid = GridSearchCV(gb_model, gboost_param_grid, cv=10, verbose=3)
gb_grid.fit(train_X_SmallPCA, train_Y_SmallPCA)
print('Best parameters for Gradient Boost Model are:', gb_grid.best_params_)
# Out:
# Fitting 10 folds for each of 24 candidates, totalling 240 fits
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6585560962602494, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.6min remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6622225184987668, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  3.3min remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6556896206919539, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6585333333333333, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6615333333333333, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6569333333333334, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6597333333333333, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.653510234015601, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6565104340289353, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6551103406893793, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6576228251449904, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6632224518365443, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6562895806946204, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6610666666666667, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6606666666666666, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6576, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6582, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6543769584638975, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6551103406893793, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6567104473631575, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6591560562629158, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6622891807212853, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6568228784747684, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6592666666666667, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6611333333333334, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6558, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6594666666666666, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6542436162410827, total= 1.5min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.655377025135009, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6552436829121941, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6592893807079528, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6617558829411373, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6555562962469169, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6601333333333333, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6612, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6578666666666667, total= 1.6min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6588, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6547103140209347, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6552436829121941, total= 1.7min
# [CV] learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6574438295886392, total= 1.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6654223051796547, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6675554963002467, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6600893273781748, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6631333333333334, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6657333333333333, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6631333333333334, total= 3.6min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6668, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6597773184878992, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6623108207213815, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6625108340556037, total= 3.6min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6653556429571362, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6684887674155057, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6591560562629158, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6666666666666666, total= 3.8min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6648, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6640666666666667, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6679333333333334, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6588439229281952, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6615107673844923, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6614440962730849, total= 3.7min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6647556829544697, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6682221185254317, total= 3.4min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6608892740483968, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6636, total= 3.4min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6668, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6631333333333334, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6658666666666667, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6587105807053804, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6632442162810854, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.663177545169678, total= 3.3min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6658889407372842, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6685554296380242, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6598226784881008, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6671333333333334, total= 3.4min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6664, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6649333333333334, total= 3.6min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6666, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6589105940396026, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6631108740582705, total= 3.5min
# [CV] learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6620441362757518, total= 3.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6686887540830612, total= 7.0min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6717552163189121, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6634224385040998, total= 7.0min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6669333333333334, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6693333333333333, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6665333333333333, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6681333333333334, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6625108340556037, total= 7.0min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6631108740582705, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6654443629575305, total= 7.1min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6669555362975802, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6702219852009866, total= 7.4min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6620225318312113, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6679333333333334, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6700666666666667, total= 7.4min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6663333333333333, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6666666666666666, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6641109407293819, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6625775051670111, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6668444562970864, total= 7.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6683554429704687, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6718218785414306, total= 6.3min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6649556696220252, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6667333333333333, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6691333333333334, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6662666666666667, total= 6.3min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6674, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6623774918327888, total= 6.3min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6654443629575305, total= 6.2min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6670444696313087, total= 6.3min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6689554029731352, total= 6.7min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6726884874341711, total= 6.7min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6622891807212853, total= 6.6min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6678666666666667, total= 6.5min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6711333333333334, total= 6.6min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6656666666666666, total= 6.7min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.669, total= 6.6min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6635775718381225, total= 6.7min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6621108073871591, total= 6.7min
# [CV] learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.01, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6652443496233083, total= 6.7min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6636890873941738, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6670888607426172, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6608226118258783, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6640666666666667, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6644666666666666, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6614666666666666, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6641333333333334, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6598439895993066, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6595106340422695, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6619107940529368, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6621558562762483, total= 1.6min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6671555229651357, total= 1.6min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6606226251583228, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6635333333333333, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6654, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6631333333333334, total= 1.6min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6634, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6591106073738249, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6614440962730849, total= 1.6min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6619774651643443, total= 1.6min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6616892207186188, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6658222785147657, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6599560029331378, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6644666666666666, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6653333333333333, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6622, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6643333333333333, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6591772784852323, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.660844056270418, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6611774118274552, total= 1.4min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6628224785014333, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6664889007399507, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6604893007132858, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6662666666666667, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6653333333333333, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6636666666666666, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6642, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.660377358490566, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6623108207213815, total= 1.5min
# [CV] learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=8, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6619774651643443, total= 1.5min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6682887807479502, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6714219052063196, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6623558429438038, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6652, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6702, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6683333333333333, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6687333333333333, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6629775318354557, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6645109673978266, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.667711180745383, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6666888874075062, total= 3.1min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6706886207586161, total= 3.0min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6618892073861743, total= 3.0min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6666, total= 3.0min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6697333333333333, total= 3.1min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6678, total= 3.0min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6680666666666667, total= 3.0min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6639775985065671, total= 3.1min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6651110074004933, total= 3.1min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6640442696179746, total= 3.1min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6684221051929872, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6707552829811346, total= 2.8min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6625558296113593, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6665333333333333, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6683333333333333, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6661333333333334, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6676666666666666, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6642442829521968, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6638442562837522, total= 2.8min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6687779185279019, total= 2.7min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6677554829678022, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6706219585360976, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6623558429438038, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6666, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6686, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6669333333333334, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6686666666666666, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6619774651643443, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6647776518434563, total= 2.9min
# [CV] learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=10, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6657110474031602, total= 2.9min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6708219452036531, total= 5.4min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6724885007666156, total= 5.4min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6641557229518033, total= 5.3min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6695333333333333, total= 5.3min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6678, total= 5.3min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6702666666666667, total= 5.4min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.668, total= 5.4min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6654443629575305, total= 5.3min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6646443096206414, total= 5.4min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.7, score=0.6667111140742716, total= 5.3min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6675554963002467, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6712219185387641, total= 5.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6641557229518033, total= 5.5min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6692, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6698, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6690666666666667, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.667, total= 5.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6648443229548636, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6630442029468632, total= 5.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=5, n_estimators=200, subsample=0.8, score=0.6681112074138276, total= 5.6min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6689554029731352, total= 4.8min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6719552029864676, total= 4.8min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6635557629491368, total= 4.8min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6676, total= 4.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6669333333333334, total= 4.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6684, total= 4.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6686, total= 4.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.6647109807320488, total= 4.7min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.665844389625975, total= 4.8min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.7, score=0.667711180745383, total= 4.8min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6694220385307647, total= 5.1min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6716218918738751, total= 5.1min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6623558429438038, total= 5.0min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6683333333333333, total= 5.0min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6717333333333333, total= 5.1min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6662, total= 5.0min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6674, total= 5.1min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6666444429628642, total= 5.0min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6647109807320488, total= 5.0min
# [CV] learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8
# [CV]  learning_rate=0.02, max_depth=12, min_samples_leaf=8, n_estimators=200, subsample=0.8, score=0.6680445363024201, total= 5.0min
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed: 871.2min finished
# Best parameters for Gradient Boost Model are: {'learning_rate': 0.02, 'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200, 'subsample': 0.7}

# %%
print('Best parameters for Gradient Boost Model are:', gb_grid.best_params_)
print('Best score for Gradient Boost Model are:', gb_grid.best_score_)
# Out:
# Best parameters for Gradient Boost Model are: {'learning_rate': 0.02, 'max_depth': 12, 'min_samples_leaf': 5, 'n_estimators': 200, 'subsample': 0.7}
# Best score for Gradient Boost Model are: 0.6679866666666666

# %%
# Initialize and fit the model using PCA
Grad_boost_pca = ensemble.GradientBoostingClassifier(learning_rate=0.02, max_depth=16, min_samples_leaf=5, 
                                                 n_estimators=200, subsample=0.7)

#set start time
start_time_gb = datetime.datetime.now()

#fit and train the model
Grad_boost_pca.fit(train_X_PCA, train_Y_PCA)

# Classify, storing the result in a new variable.
y_pred_Gboost_pca = Grad_boost_pca.predict(test_X_PCA)

#get accuracy score from our model
print('Accuracy score for Gradient Boost Model: ' + str(metrics.accuracy_score(test_Y_PCA, y_pred_Gboost_pca)))

#calculate end time
end_time_gb = datetime.datetime.now()

#print the execution run time for our model
print('\nDuration: {}'.format(end_time_gb - start_time_gb))
print()

#get average accuracy score using cross validation
#Grad_boost_cvs_pca = cross_val_score(Grad_boost_pca, pca_df, Y, cv=5, verbose=3, scoring='accuracy')
#print(Grad_boost_cvs_pca)

#print('Average cross validated score from our Gradient Boosting model is: ' + str(np.mean(Grad_boost_cvs_pca)))
# Out:
# Accuracy score for Gradient Boost Model: 0.680307212889715
#
# Duration: 2:57:46.552538

# %%
#Get AUC and create ROC
# predict probabilities
probs_Gboost_pca = Grad_boost_pca.predict_proba(test_X_PCA)
# keep probabilities for the positive outcome only
probs_Gboost_pca = probs_Gboost_pca[:, 1]
# calculate AUC
Gboost_auc = roc_auc_score(test_Y_PCA, probs_Gboost_pca)
print('AUC Score: %.3f' % Gboost_auc)
# calculate roc curve
fpr_Gboost_pca, tpr_Gboost_pca, thresholds_Gboost_pca = roc_curve(test_Y_PCA, probs_Gboost_pca)
# plot no skill
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr_Gboost_pca, tpr_Gboost_pca, marker='.')
# show the plot
plt.show()

# perform classification report of the Gradient Boosting model
class_names = ['Class_0', 'Class_1']
Gboost_report = classification_report(test_Y_PCA, y_pred_Gboost_pca, target_names=class_names)
print(Gboost_report)
print()
#confusion matrix
print('Confusion Matrix:')
print(confusion_matrix(test_Y_PCA, y_pred_Gboost_pca))
# Out:
# AUC Score: 0.745
#               precision    recall  f1-score   support
#
#      Class_0       0.68      0.69      0.68    100167
#      Class_1       0.68      0.67      0.68     99434
#
#    micro avg       0.68      0.68      0.68    199601
#    macro avg       0.68      0.68      0.68    199601
# weighted avg       0.68      0.68      0.68    199601
#
#
# Confusion Matrix:
# [[68974 31193]
#  [32618 66816]]

# %% [markdown]
# The tree based algorithms, performed better than Logistic Regression and even KNN.  This makes sense because of the type of variables we have in the data.
#
# For example, consider the features using latitude and longitude to define location in the models.  These variables are categorical in nature, because each pair of the longitude and latitude coordinates in the data represent one specific location in New York City.  Being Categorical means they don't have a direct linear relationship with the binary out come variable and so logistic regression here is at a disadvantage because it works best with the assumption of typical linear regression.
#
# But tree based algorithms can handle categorical data better than models based on linear regression.  Fro example, even the basic decision tree performed better (67% accuracy score) vs. the Logistic Regression (61% accuracy score).
#
# This is because the decision tree algorithm analyzes the data set to create a set of rules or questions based on the best attribute-value pair from the data, to create a split at each node.  Considering the categorical data that we have, the tree was able to subset the data according to the value of each sample for the attribute chosen at each node.
#
# The Random Forest model performed alittle better than the simple decision tree, with an accuracy score of 68%.  Given the fact that with the Random forest Algorithm, each tree selects a subset of the observations in the data, having a mix of categorical and continuous variables and close to 800,000 observations, and building the forest with 100 trees allowed the model to learn more and give a better accuracy then the aforementioned decision tree.
#
# Gradient boosting performed about as good as the Random Forest (scored 68%), but the run time was over two hours longer, without a significant improvement in accuracy score.
#
# KNN performed decently (score of 67%), but not as good as the Random Forest.  KNN works best with continuous variables, but we also had alot of categorical variables.
#
# Logistic Regression performed the worst.  Several factors may have led to this, such as high multicollinearity between the variables, and no real linear relationship between the independent variables.  I could have tried to create features by applying transformations to the independent variables in the data, such as the latitude and longitude variables, but it wouldn't make any logical sense.  Or I could have applied the transformation on one of the continuous variables, such as "Scheduled_HourOfDay", which I found to be the most important variable in the Random Forest, but again it makes no logical sense to have a linear relationship with "Scheduled_HourOfDay" and the output variable.  As Hour of day increases and gets around the afternoon rush hours, it may hint at a linear connection between the hour of day and output variable, but this isn't going to continue indefinitely.  For example, as we approach the late night 22nd or 23rd hour, the relationship and outcome is probably totally different.
#
# I created two features by squaring "dist" and "VehicleToDestination", in order to create a linear relationship between these independent variables and the output variable.  But it did not help the accuracy score improve.
#
# I would choose the Random Forest model above the others because of its accuracy, and efficiency.
#
# In addition to the insights I got from exploring this data, I would like to know how the experience of the driver relates the the reliability of a bus.  Also, it would be nice to have weather conditions as part of the dataset, to show if that had adverse effect on the bus being on time or not on time.
